# %%
import requests
from requests import get
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

from gensim.models import Word2Vec
from sklearn.manifold import TSNE
import nltk

import re

import PyQt5

# %matplotlib qt

# %%
nltk.download('stopwords')

STOP_WORDS = nltk.corpus.stopwords.words()
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/josephepstein/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
headers = {"Accept-Language": "en-US, en;q=0.5"}

def clean_sentence(val):
    "remove chars that are not letters or numbers, downcase, then remove stop words"
    regex = re.compile('([^\s\w]|_)+')
    sentence = regex.sub('', val).lower()
    sentence = sentence.split(" ")
    
    for word in list(sentence):
        if word in STOP_WORDS:
            sentence.remove(word)
            continue

        if len(word) < 3:
            sentence.remove(word)
            continue
            
    return sentence

# %%
def blog_scraper( blog_url, post_link_selector, post_content_selector):
    
    post_text_array = []
    
    pages = np.arange(2, 50)

    for page in pages:

        blog = requests.get( blog_url + str(page), headers=headers)

        soup = BeautifulSoup(blog.text, 'html.parser')

        post_links = soup.select( post_link_selector )

        for post_link in post_links:
            
            if len(post_text_array) == 50:
                
                return post_text_array
            
            blog = requests.get(post_link['href'])
                        
            post_soup = BeautifulSoup(blog.text, 'html.parser')
            
            post_text = post_soup.select_one( post_content_selector ).text
                        
            post_text_array.append(post_text)

# %%
blog_url = 'https://www.datasciencecentral.com/profiles/blog/list?promoted=1&page='
post_link_selector = '#xg .xg_module_body .title a:nth-child(2)'
post_content_selector = '#xg .postbody'

data_science_blogs = blog_scraper( blog_url, post_link_selector, post_content_selector )

# %%
data_science_blogs_split = [clean_sentence(row) for row in data_science_blogs]

# %%
data_science_blogs_split[:2]
# Out:
# [['\n\nin',
#   'blog',
#   'introduce',
#   'package',
#   'heterogeneous',
#   'ensemble',
#   'learning',
#   'classification',
#   'regression',
#   'fully',
#   'automated\xa0it',
#   'significantly',
#   'lowers',
#   'barrier',
#   'practitioners',
#   'apply',
#   'heterogeneous',
#   'ensemble',
#   'learning',
#   'techniques',
#   'amateur',
#   'fashion',
#   'everyday',
#   'predictive',
#   'problems\nbefore',
#   'dwell',
#   'package',
#   'details',
#   'lets',
#   'start',
#   'understanding',
#   'basic',
#   'concepts\n\nwhy',
#   'ensemble',
#   'learning\ngenerally\xa0predictions',
#   'become',
#   'unreliable',
#   'input',
#   'sample',
#   'training',
#   'distribution',
#   'bias',
#   'data',
#   'distribution',
#   'error',
#   'prone',
#   'noise',
#   'approaches',
#   'require',
#   'changes',
#   'network',
#   'architecture',
#   'fine',
#   'tuning',
#   'balanced',
#   'data',
#   'increasing',
#   'model',
#   'size',
#   'etc',
#   'selection',
#   'algorithm',
#   'plays',
#   'vital',
#   'role',
#   'scalability',
#   'learning',
#   'ability',
#   'decrease',
#   'complex',
#   'datasets',
#   'combining',
#   'multiple',
#   'learners',
#   'effective',
#   'approach',
#   'applied',
#   'many',
#   'realworld',
#   'problems',
#   'ensemble',
#   'learners',
#   'combine',
#   'diverse',
#   'collection',
#   'predictions',
#   'individual',
#   'base',
#   'models',
#   'produce',
#   'composite',
#   'predictive',
#   'model',
#   'accurate',
#   'robust',
#   'components',
#   'meta',
#   'ensemble',
#   'learning',
#   'minimize',
#   'generalization',
#   'error',
#   'extent',
#   'irrespective',
#   'data',
#   'distribution',
#   'number',
#   'classes',
#   'choice',
#   'algorithm',
#   'number',
#   'models',
#   'complexity',
#   'datasets',
#   'etc',
#   'summary',
#   'predictive',
#   'models',
#   'able',
#   'generalize',
#   'better\nhow',
#   'build',
#   'models',
#   'stable',
#   'fashion',
#   'minimizing',
#   'underfittingoverfitting',
#   'critical',
#   'overall',
#   'outcome',
#   'solution',
#   'ensemble',
#   'metalearning',
#   'heterogeneous',
#   'collection',
#   'base',
#   'learners\n\ncommon',
#   'ensemble',
#   'learning',
#   'techniques\nthe',
#   'different',
#   'popular',
#   'ensemble',
#   'techniques',
#   'referred',
#   'figure',
#   'stacked',
#   'generalization',
#   'general',
#   'method',
#   'using',
#   'highlevel',
#   'model',
#   'combine',
#   'lower',
#   'level',
#   'models',
#   'achieve',
#   'greater',
#   'predictive',
#   'accuracy',
#   'bagging',
#   'method',
#   'independent',
#   'base',
#   'models',
#   'derived',
#   'bootstrap',
#   'samples',
#   'original',
#   'dataset',
#   'boosting',
#   'method',
#   'grows',
#   'ensemble',
#   'dependent',
#   'fashion',
#   'iteratively',
#   'adjusts',
#   'weight',
#   'observation',
#   'based',
#   'past',
#   'prediction',
#   'several',
#   'extensions',
#   'bagging',
#   'boosting\n\noverview\nmetaensembler\xa0is',
#   'package',
#   'automated',
#   'metalearning',
#   'classification',
#   'regression',
#   'functionalities',
#   'provided',
#   'includes',
#   'simple',
#   'user',
#   'input',
#   'based',
#   'predictive',
#   'modeling',
#   'selection',
#   'choice',
#   'algorithms',
#   'trainvalidationtest',
#   'split',
#   'model',
#   'valuations',
#   'easy',
#   'guided',
#   'unseen',
#   'data',
#   'prediction',
#   'help',
#   'users',
#   'build',
#   'stack',
#   'ensembles',
#   'core',
#   'aim',
#   'package',
#   'cater',
#   'larger',
#   'audiences',
#   'general\xa0metaensembler\xa0significantly',
#   'lowers',
#   'barrier',
#   'practitioners',
#   'apply',
#   'heterogeneous',
#   'ensemble',
#   'learning',
#   'techniques',
#   'amateur',
#   'fashion',
#   'everyday',
#   'predictive',
#   'problems\nusing',
#   'metaensembler\nthe',
#   'package',
#   'consists',
#   'following',
#   'components\n\nensemble',
#   'classifiers',
#   'training',
#   'prediction\nensemble',
#   'regressor',
#   'training',
#   'prediction\nmodel',
#   'evaluation',
#   'model',
#   'results',
#   'observation',
#   'prediction',
#   'test',
#   'data',
#   'new',
#   'unseen',
#   'data',
#   'prediction',
#   'disk',
#   'write',
#   'performance',
#   'charts',
#   'saving',
#   'prediction',
#   'results\n\nall',
#   'functions',
#   'intuitive',
#   'use',
#   'illustrated',
#   'examples',
#   'covering',
#   'classification',
#   'regression',
#   'problem',
#   'general\ngetting',
#   'started\nthe',
#   'package',
#   'installed',
#   'directly',
#   'cran\ninstall',
#   'rconsole\xa0installpackagesmetaensembler\n\nhowever',
#   'latest',
#   'stable',
#   'version',
#   'could',
#   'found',
#   'on\xa0github',
#   'installed',
#   'using',
#   'devtools',
#   'package\ninstall',
#   'github\nifrequiredevtools',
#   'installpackagesdevtools\ndevtoolsinstallgithubrepo',
#   'ajayarunachalammetaensembler',
#   'ref',
#   'main\n\n\nusage\nlibrarymetaensembler\nsetseed111\n\n\ntraining',
#   'ensemble',
#   'classification',
#   'model',
#   'simple',
#   'oneline',
#   'call',
#   'the\xa0ensemblerclassifier\xa0function',
#   'following',
#   'ways',
#   'either',
#   'passing',
#   'csv',
#   'file',
#   'directly',
#   'imported',
#   'dataframe',
#   'takes',
#   'account',
#   'arguments',
#   'following',
#   'order',
#   'starting',
#   'dataset',
#   'outcomeresponse',
#   'variable',
#   'index',
#   'base',
#   'learners',
#   'final',
#   'learner',
#   'trainvalidationtest',
#   'split',
#   'ratio',
#   'unseen',
#   'data\n\nensemblerreturn',
#   '\xa0ensemblerclassifieriris1130',
#   'ctreebagrpart',
#   'gbm',
#   '060',
#   '020',
#   '020',
#   'readcsvunseendatacsv\n\n\xa0',
#   'or\nunseennewdatatesting',
#   'iris130150\nensemblerreturn',
#   '\xa0ensemblerclassifieriris1130',
#   'ctreebagrpart',
#   'gbm',
#   '060',
#   '020',
#   '020',
#   'unseennewdatatesting\n\nthe',
#   'function',
#   'returns',
#   'following',
#   'test',
#   'data',
#   'predictions',
#   'prediction',
#   'labels',
#   'model',
#   'result',
#   'finally',
#   'predictions',
#   'unseen',
#   'data\ntestpreddata',
#   'dataframeensemblerreturn1\ntabletestpreddataactuallabel\ntableensemblerreturn2\n\n',
#   'performance',
#   'comparison',
#   '\nmodelresult',
#   'ensemblerreturn3\nmodelresult\n\n',
#   'unseen',
#   'data',
#   '\nunseenpreddata',
#   'dataframeensemblerreturn4\ntableunseenpreddataunseenpreddata\n\n\ntraining',
#   'ensemble',
#   'regression',
#   'model',
#   'oneline',
#   'call',
#   'the\xa0ensemblerregression\xa0function',
#   'following',
#   'ways',
#   'either',
#   'passing',
#   'csv',
#   'file',
#   'directly',
#   'imported',
#   'dataframe',
#   'takes',
#   'account',
#   'arguments',
#   'following',
#   'order',
#   'starting',
#   'dataset',
#   'outcomeresponse',
#   'variable',
#   'index',
#   'base',
#   'learners',
#   'final',
#   'learner',
#   'trainvalidationtest',
#   'split',
#   'ratio',
#   'unseen',
#   'data\n\nhouseprice',
#   'readcsvfile',
#   'dataregressionhousepricedatacsv\nunseennewdatatestinghouseprice',
#   'houseprice250414\nwritecsvunseennewdatatestinghouseprice',
#   'unseenhousepriceregressioncsv',
#   'fileencoding',
#   'utf8',
#   'rownames',
#   'f\nensemblerreturn',
#   '\xa0ensemblerregressionhouseprice1250',
#   'ctreebagrpart',
#   'gbm',
#   '060',
#   '020',
#   '020',
#   'readcsvunseenhousepriceregressioncsv\n\n\xa0',
#   'or\nensemblerreturn',
#   '\xa0ensemblerregressionhouseprice1250',
#   'ctreebagrpart',
#   'gbm',
#   '060',
#   '020',
#   '020',
#   'unseennewdatatestinghouseprice',
#   '\n\nthe',
#   'function',
#   'returns',
#   'following',
#   'test',
#   'data',
#   'predictions',
#   'prediction',
#   'values',
#   'model',
#   'result',
#   'finally',
#   'unseen',
#   'data',
#   'predictions\ntestpreddata',
#   'dataframeensemblerreturn1\n\n\xa0',
#   'performance',
#   'comparison\xa0',
#   '\nmodelresult',
#   'ensemblerreturn3\nmodelresult\nwritecsvmodelresult1',
#   'performancechartcsv\n\n',
#   'unseen',
#   'data\xa0',
#   '\nunseenpreddata',
#   'dataframeensemblerreturn4\n\nexamples\ndemo',
#   'classification\nlibrarymetaensembler\nattachiris\ndatairis\nunseennewdatatesting',
#   'iris130150\nwritecsvunseennewdatatesting',
#   'unseencheckcsv',
#   'fileencoding',
#   'utf8',
#   'rownames',
#   'f\nensemblerreturn',
#   'ensemblerclassifieriris1130',
#   'ctreebagrpart',
#   'gbm',
#   '060',
#   '020',
#   '020',
#   'unseennewdatatesting\ntestpreddata',
#   'dataframeensemblerreturn1\ntabletestpreddataactuallabel\ntableensemblerreturn2\n\nperformance',
#   'comparison\nmodelresult',
#   'ensemblerreturn3\nmodelresult\nactmybar',
#   'qplottestpreddataactuallabel',
#   'geom',
#   'bar\nactmybar\npredmybar',
#   'qplottestpreddatapredictions',
#   'geom',
#   'bar\npredmybar\nacttbl',
#   'tablegrobtsummarytestpreddataactuallabel\npredtbl',
#   'tablegrobtsummarytestpreddatapredictions\nggsavetestdataactualvspredictedchartpdfgridarrangeacttbl',
#   'predtbl\nggsavetestdataactualvspredictedplotpdfgridarrangeactmybar',
#   'predmybar\nunseen',
#   'data\nunseenpreddata',
#   'dataframeensemblerreturn4\ntableunseenpreddataunseenpreddata\ntableunseennewdatatestingspecies\n\ndemo',
#   'regression\nlibrarymetaensembler\ndatarock\nunseenrockdata',
#   'rock3048\nensemblerreturn',
#   'ensemblerregressionrock130',
#   '4clm',
#   '040',
#   '030',
#   '030',
#   'unseenrockdata\ntestpreddata',
#   'dataframeensemblerreturn1\n\nperformance',
#   'comparison\nmodelresult',
#   'ensemblerreturn3\nmodelresult\nwritecsvmodelresult1',
#   'performancechartcsv\n\nunseen',
#   'data\nunseenpreddata',
#   'dataframeensemblerreturn4\n\n\ncomprehensive',
#   'examples\nmore',
#   'demo',
#   'examples',
#   'found',
#   'the\xa0demor\xa0file',
#   'see',
#   'results',
#   'run',
#   'rscript',
#   'demor',
#   'terminal\n\ncontact\nif',
#   'implementation',
#   'would',
#   'like',
#   'see',
#   'add',
#   'examples',
#   'feel',
#   'free',
#   'always',
#   'reach',
#   'email\xa0protected\n\nalways',
#   'keep',
#   'learning',
#   'sharing',
#   'knowledge'],
#  ['\n\nin',
#   'past',
#   'slow',
#   'evaluation',
#   'mathematical',
#   'functions',
#   'large',
#   'memory',
#   'footprint',
#   'significant',
#   'drawbacks',
#   'java',
#   'compared',
#   'numeric',
#   'computations',
#   'scientific',
#   'data',
#   'analysis',
#   'however',
#   'recent',
#   'enhancements',
#   'java',
#   'virtual',
#   'machine',
#   'jvm',
#   'enabled',
#   'faster',
#   'better',
#   'numerical',
#   'computing',
#   'due',
#   'several',
#   'enhancements',
#   'evaluating',
#   'trigonometric',
#   'functions\nin',
#   'article',
#   'use',
#   'datamelt',
#   'httpsdatameltorg',
#   'benchmarks',
#   'let',
#   'consider',
#   'following',
#   'algorithm',
#   'implemented',
#   'groovy',
#   'dynamicallytyped',
#   'language',
#   'shown',
#   'uses',
#   'large',
#   'loop',
#   'repeatedly',
#   'calling',
#   'cos',
#   'functions',
#   'save',
#   'lines',
#   'file',
#   'extension',
#   'goovy',
#   'run',
#   'datamelt\n',
#   'import',
#   'javalangmath',
#   'long',
#   'systemnanotime\ndouble',
#   'x0\nfor',
#   'int',
#   '1e8',
#   'i\nxxmathsinimathcosi\nitime',
#   'systemnanotime',
#   'then1e9\nprintln',
#   'time',
#   'itime',
#   'sec',
#   'resultx\n\nthe',
#   'execution',
#   'groovy',
#   'code',
#   'typically',
#   '1020',
#   'faster',
#   'equivalent',
#   'code',
#   'implemented',
#   'python\n',
#   'import',
#   'mathtime',
#   'timetime\nx0\nfor',
#   'xrangeint1e8\nxxmathsinimathcosi\nitime',
#   'timetime',
#   'then\nprinttimeitime',
#   'sec',
#   'resultx\n\nnote',
#   'cpython2',
#   'version',
#   '272',
#   'faster',
#   'cpython3',
#   'version',
#   '342',
#   'cpython',
#   'interpreters',
#   'slower',
#   'example',
#   'groovy\nthe',
#   'algorithm',
#   'reimplemented',
#   'java\n',
#   'import',
#   'javalangmath',
#   'public',
#   'class',
#   'example',
#   '\npublic',
#   'static',
#   'void',
#   'mainstring',
#   'args',
#   '\nlong',
#   'systemnanotime\ndouble',
#   'x0\nfor',
#   'int',
#   'int1e8',
#   'i\nxxmathsinimathcosi\ndouble',
#   'itime',
#   'systemnanotime',
#   'then1e9\nsystemoutprintlntime',
#   'calculations',
#   'sec',
#   'itimen\nsystemoutprintlnpi',
#   'n\n\n\n\nand',
#   'processed',
#   'using',
#   'datamelt',
#   'openjdk13',
#   'increases',
#   'execution',
#   'speed',
#   'factor',
#   'compared',
#   'groovy',
#   'dynamic',
#   'language\nsimilar',
#   'benchmarks',
#   'java',
#   'code',
#   'carried',
#   'repeating',
#   'calculation',
#   'using',
#   'java',
#   'jdk18',
#   'released',
#   'march',
#   '2014',
#   'computation',
#   'factor',
#   'slower',
#   'openjdk13',
#   'due',
#   'less',
#   'optimized',
#   'code',
#   'evaluation',
#   'trigonometric',
#   'functions',
#   'jdk18',
#   'earlier',
#   'versions',
#   'confirms',
#   'significant',
#   'improvements',
#   'numeric',
#   'computations',
#   'recent',
#   'jvm',
#   'compared',
#   'previous',
#   'releases\nthe',
#   'question',
#   'code',
#   'profiling',
#   'using',
#   'different',
#   'implementations',
#   'complex',
#   'problem',
#   'plan',
#   'explore',
#   'possible',
#   'scenarios',
#   'article',
#   'main',
#   'conclusion',
#   'draw',
#   'section',
#   'processing',
#   'speed',
#   'code',
#   'implements',
#   'mathematical',
#   'functions',
#   'numeric',
#   'calculations',
#   'substantially',
#   'better',
#   'groovy',
#   'cpython2',
#   'cpython3',
#   'observed',
#   'performance',
#   'improvements',
#   'dynamicallytyped',
#   'languages',
#   'implemented',
#   'java',
#   'due',
#   'recent',
#   'enhancements',
#   'modern',
#   'jvms',
#   'leading',
#   'large',
#   'factor',
#   'speed',
#   'evaluations',
#   'mathematical',
#   'functions\nsergei',
#   'chekanov']]

# %%
model = Word2Vec(data_science_blogs_split, min_count=1,size= 50,workers=3, window =3, sg = 1)

# %%
def tsne_plot(model):
    "Creates and TSNE model and plots it"
    labels = []
    tokens = []
    for word in model.wv.vocab:
        tokens.append(model[word])
        labels.append(word)
        
    tsne_model = TSNE(perplexity=30, n_components=2, init='pca', n_iter=250, random_state=23)
    new_values = tsne_model.fit_transform(tokens)
    
    x = []
    y = []
    for value in new_values:
        x.append(value[0])
        y.append(value[1])
        
    plt.figure(figsize=(16, 16))
    for i in range(len(x)):
        plt.scatter(x[i],y[i])
        plt.annotate(labels[i],
            xy=(x[i], y[i]),
            xytext=(5, 2),
            textcoords='offset points',
            ha='right',
            va='bottom')
        
    plt.show()
        
tsne_plot(model)
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:6: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).

# %%
### Maybe refine this to top 250 most common words
### Improve word cleaning
### Add PCA option to plotting
