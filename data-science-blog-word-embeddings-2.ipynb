# %%
import requests
from requests import get
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

from gensim.models import Word2Vec
from sklearn.manifold import TSNE
import nltk

import string
import re
RE_PUNCT = re.compile('([%s])+' % re.escape(string.punctuation), re.UNICODE)

import PyQt5

# %matplotlib qt

# %%
nltk.download('stopwords')

STOP_WORDS = nltk.corpus.stopwords.words()
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/josephepstein/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
headers = {"Accept-Language": "en-US, en;q=0.5", "User-Agent": "Mozilla/5.0"}

def clean_sentence(sentence):

    sentence = RE_PUNCT.sub(" ", sentence).lower().split()
    return_sentence = sentence
    
    #print(sentence)
    
    for word in sentence:
        #print(word)
        if word in STOP_WORDS or len(word) < 3:
            return_sentence = list(filter((word).__ne__, return_sentence))
#             if word == 'go':
#                 print(return_sentence)
#                 print('\n\n\n\n\n\n\n\n\n\n\n\n')
#             return_sentence.remove(word)
#             if word == 'go':
#                 print(return_sentence)
#                 print('\n\n\n\n\n\n\n\n\n\n\n\n')
    return return_sentence

# %%
def count_words(split_sentences):
    word_count_dict = {}
    
    for sentence in split_sentences:
        for word in sentence:
            if word not in word_count_dict:
                word_count_dict[word] = 0
        
            word_count_dict[word] += 1
        
    return word_count_dict

# %%
def blog_scraper( blog_url, post_link_selector, post_content_selector):
    
    post_text_array = []
    
    pages = np.arange(2, 50)

    for page in pages:
        
        blog = requests.get( blog_url + str(page), headers=headers)

        soup = BeautifulSoup(blog.text, 'html.parser')

        post_links = soup.select( post_link_selector )

        for post_link in post_links:
                        
            if len(post_text_array) >= 100:
                
                return post_text_array
            
            blog = requests.get(post_link['href'], headers=headers)
            
            post_soup = BeautifulSoup(blog.text, 'html.parser')
            
            post_text = post_soup.select_one( post_content_selector ).text
                        
            post_text_array.append(post_text)
    
    return post_text_array

# %%
##/# Recreate using a dictionary of sites, and their link/content selectors

datasciencecentral_url = 'https://www.datasciencecentral.com/profiles/blog/list?promoted=1&page='
datasciencecentral_link_selector = '#xg .xg_module_body .title a:nth-child(2)'
datasciencecentral_content_selector = '#xg .postbody'

smartdatacollective_url = 'https://www.smartdatacollective.com/page/'
smartdatacollective_link_selector = '.content-inner .p-outer .p-footer a.btn'
smartdatacollective_content_selector = '.single-content .entry-content'

starbridgepartners_url = 'https://starbridgepartners.com/data-science-report/page/'
starbridgepartners_link_selector = 'article.post .entry-title-link'
starbridgepartners_content_selector = 'article'

data_science_blogs = blog_scraper( datasciencecentral_url, datasciencecentral_link_selector, datasciencecentral_content_selector )
print(len(data_science_blogs))
data_science_blogs.extend(blog_scraper( smartdatacollective_url, smartdatacollective_link_selector, smartdatacollective_content_selector ))
print(len(data_science_blogs))
data_science_blogs.extend(blog_scraper( starbridgepartners_url, starbridgepartners_link_selector, starbridgepartners_content_selector ))
print(len(data_science_blogs))
# Out:
# 100
# 200
# 300

# %%
data_science_blogs_split = [clean_sentence(row) for row in data_science_blogs]

word_count_dict = count_words(data_science_blogs_split)

# %%
print(data_science_blogs_split[0])
# Out:
# ['start', 'incorporating', 'machine', 'learning', 'models', 'user', 'applications', 'question', 'comes', '“when', 'model', 'good', 'enough', 'deploy', 'simply', 'single', 'right', 'answer', 'clear', 'cut', 'measure', 'machine', 'learning', 'model', 'ready', 'put', 'production', 'set', 'thought', 'experiments', 'new', 'model', 'identify', 'goal', 'machine', 'learning', 'model', 'trying', 'decide', 'machine', 'learning', 'model', 'ready', 'deployment', 'helpful', 'circle', 'back', 'algorithm’s', 'original', 'goal', 'trying', 'predict', 'customer', 'churn', 'reach', 'client', 'intent', 'automatically', 'approve', 'deny', 'someone’s', 'credit', 'application', 'use', 'case', 'model', 'determine', 'stringent', 'requirements', 'deployment', 'instance', 'machine', 'learning', 'model', 'simply', 'suggesting', 'things', 'user', 'deployment', 'requirements', 'wildly', 'different', 'compared', 'algorithm', 'designed', 'make', 'decisions', 'automatically', 'autonomous', 'driving', 'space', 'example', 'illustrated', 'dilemma', 'six', 'levels', 'autonomy', 'might', 'imagine', 'subsequent', 'level', 'would', 'stricter', 'requirements', 'levels', 'vehicle', 'autonomy', 'explained', 'simply', 'put', 'depending', 'type', 'model', 'may', 'able', 'deploy', 'right', 'away', 'potentially', 'need', 'roll', 'stages', 'different', 'models', 'require', 'different', 'thresholds', 'decide', 'appropriate', 'case', 'case', 'basis', 'strive', 'metric', 'combination', 'metrics', 'decides', 'whether', 'model', 'ready', 'deployment', 'depends', 'use', 'case', 'accuracy', 'vital', 'machine', 'learning', 'model', 'often', 'talked', 'without', 'accurate', 'predictions', 'purpose', 'deploying', 'algorithm', 'strive', 'best', 'accuracy', 'within', 'reasonable', 'limitations', 'however', 'depending', 'use', 'case', 'direct', 'test', 'accuracy', 'might', 'metric', 'use', 'might', 'even', 'important', 'example', 'let', 'imagine', 'model', 'would', 'decide', 'whether', 'someone', 'needs', 'surgery', 'would', 'problem', 'operate', 'sick', 'people', 'could', 'consider', 'operating', 'healthy', 'patient', 'much', 'significant', 'mistake', 'cases', 'like', 'false', 'positives', 'dangerous', 'metrics', 'like', 'precision', 'recall', 'score', 'might', 'appropriate', 'keep', 'simple', 'article', 'let’s', 'focus', 'accuracy', 'practical', 'terms', 'you’ll', 'confirming', 'accuracy', 'model', 'two', 'phases', 'training', 'phase', 'separate', 'testing', 'phase', 'evaluate', 'accuracy', 'training', 'phase', 'you’ll', 'generally', 'set', 'aside', 'portion', 'data', 'set', 'validation', 'data', 'use', 'set', 'validate', 'trained', 'model', 'training', 'data', 'validation', 'data', 'used', 'several', 'times', 'find', 'optimal', 'hyperparameters', 'michael', 'mccourt', 'sigopt', 'wrote', 'data', 'split', 'practical', 'mlops', 'get', 'ready', 'production', 'models', 'testing', 'phase', 'evaluate', 'trained', 'model’s', 'accuracy', 'using', 'data', 'hasn’t', 'used', 'training', 'iterations', 'test', 'whether', 'model', 'generalize', 'words', 'produce', 'accurate', 'predictions', 'new', 'data', 'model', 'memorized', 'answers', 'training', 'validation', 'data', 'term', 'used', 'overfitting', 'model', 'performs', 'well', 'training', 'fails', 'testing', 'cassie', 'kozyrkov', 'google', 'done', 'fantastic', 'short', 'explainer', 'validating', 'testing', 'codify', 'decisions', 'engineering', 'perspective', 'criteria', 'set', 'model', 'important', 'making', 'sure', 'codified', 'machine', 'learning', 'pipeline', 'accuracy', 'requirements', 'written', 'baselines', 'within', 'machine', 'learning', 'pipeline', 'sure', 'adhered', 'newly', 'deployed', 'model', 'serve', 'benchmark', 'future', 'models', 'may', 'always', 'compare', 'new', 'iterations', 'production', 'model', 'testing', 'phase', 'similarly', 'perform', 'data', 'split', 'training', 'validation', 'testing', 'data', 'part', 'training', 'pipeline', 'rather', 'manual', 'process', 'separate', 'script', 'production', 'setting', 'purpose', 'trai ...

# %%
print(len(data_science_blogs_split))
# Out:
# 300

# %%
model = Word2Vec(data_science_blogs_split, min_count=1,size= 50,workers=3, window =3, sg = 1)

# %%
### Make general plotting function with PCA

def tsne_plot(model, top_n=-1, vocab=model.wv.vocab):
    "Creates and TSNE model and plots it"
    labels = []
    tokens = []
    
    if top_n != -1 and vocab!=model.wv.vocab:
        
        counter = 0
        
        for counter in range(0, top_n):
            tokens.append(model[max(vocab, key=vocab.get)])
            labels.append(max(vocab, key=vocab.get))
            vocab.pop(max(vocab, key=vocab.get))
    else:
        for word in model.wv.vocab:
            tokens.append(model[word])
            labels.append(word)
        
    tsne_model = TSNE(perplexity=100, n_components=2, init='pca', n_iter=1000, random_state=23)
    new_values = tsne_model.fit_transform(tokens)
    
    x = []
    y = []
    for value in new_values:
        x.append(value[0])
        y.append(value[1])
        
    plt.figure(figsize=(16, 16))
    for i in range(len(x)):
        plt.scatter(x[i],y[i])
        plt.annotate(labels[i],
            xy=(x[i], y[i]),
            xytext=(5, 2),
            textcoords='offset points',
            ha='right',
            va='bottom')
        
    plt.show()

# %%
### Maybe refine this to top 250 most common words
### Improve word cleaning
### Add PCA option to plotting

# %%
model.wv.vocab
# Out:
# {'start': <gensim.models.keyedvectors.Vocab at 0x13a4f82d0>,
#  'incorporating': <gensim.models.keyedvectors.Vocab at 0x13a4f8350>,
#  'machine': <gensim.models.keyedvectors.Vocab at 0x13a4f8410>,
#  'learning': <gensim.models.keyedvectors.Vocab at 0x13a4f8450>,
#  'models': <gensim.models.keyedvectors.Vocab at 0x13a4f84d0>,
#  'user': <gensim.models.keyedvectors.Vocab at 0x13a4f8550>,
#  'applications': <gensim.models.keyedvectors.Vocab at 0x13a4f8590>,
#  'question': <gensim.models.keyedvectors.Vocab at 0x13a4f85d0>,
#  'comes': <gensim.models.keyedvectors.Vocab at 0x13a4f8490>,
#  '“when': <gensim.models.keyedvectors.Vocab at 0x13a4f8510>,
#  'model': <gensim.models.keyedvectors.Vocab at 0x13a4f8610>,
#  'good': <gensim.models.keyedvectors.Vocab at 0x13a4f8650>,
#  'enough': <gensim.models.keyedvectors.Vocab at 0x13a4f8690>,
#  'deploy': <gensim.models.keyedvectors.Vocab at 0x13a4f86d0>,
#  'simply': <gensim.models.keyedvectors.Vocab at 0x13a4f8710>,
#  'single': <gensim.models.keyedvectors.Vocab at 0x13a4f8750>,
#  'right': <gensim.models.keyedvectors.Vocab at 0x13a4f8790>,
#  'answer': <gensim.models.keyedvectors.Vocab at 0x13a4f87d0>,
#  'clear': <gensim.models.keyedvectors.Vocab at 0x13a4f8810>,
#  'cut': <gensim.models.keyedvectors.Vocab at 0x13a4f8850>,
#  'measure': <gensim.models.keyedvectors.Vocab at 0x13a4f8890>,
#  'ready': <gensim.models.keyedvectors.Vocab at 0x13a4f88d0>,
#  'put': <gensim.models.keyedvectors.Vocab at 0x13a4f8910>,
#  'production': <gensim.models.keyedvectors.Vocab at 0x13a4f8950>,
#  'set': <gensim.models.keyedvectors.Vocab at 0x13a4f8990>,
#  'thought': <gensim.models.keyedvectors.Vocab at 0x13a4f89d0>,
#  'experiments': <gensim.models.keyedvectors.Vocab at 0x13a4f8a10>,
#  'new': <gensim.models.keyedvectors.Vocab at 0x13a4f8a50>,
#  'identify': <gensim.models.keyedvectors.Vocab at 0x13a4f8a90>,
#  'goal': <gensim.models.keyedvectors.Vocab at 0x13a4f8ad0>,
#  'trying': <gensim.models.keyedvectors.Vocab at 0x13a4f8b10>,
#  'decide': <gensim.models.keyedvectors.Vocab at 0x13a4f8b50>,
#  'deployment': <gensim.models.keyedvectors.Vocab at 0x13a4f8b90>,
#  'helpful': <gensim.models.keyedvectors.Vocab at 0x13a4f8bd0>,
#  'circle': <gensim.models.keyedvectors.Vocab at 0x13a4f8c10>,
#  'back': <gensim.models.keyedvectors.Vocab at 0x13a4f8c50>,
#  'algorithm’s': <gensim.models.keyedvectors.Vocab at 0x13a4f8c90>,
#  'original': <gensim.models.keyedvectors.Vocab at 0x13a4f8cd0>,
#  'predict': <gensim.models.keyedvectors.Vocab at 0x13a4f8d10>,
#  'customer': <gensim.models.keyedvectors.Vocab at 0x13a4f8d50>,
#  'churn': <gensim.models.keyedvectors.Vocab at 0x13a4f8d90>,
#  'reach': <gensim.models.keyedvectors.Vocab at 0x13a4f8dd0>,
#  'client': <gensim.models.keyedvectors.Vocab at 0x13a4f8e10>,
#  'intent': <gensim.models.keyedvectors.Vocab at 0x13a4f8e50>,
#  'automatically': <gensim.models.keyedvectors.Vocab at 0x13a4f8e90>,
#  'approve': <gensim.models.keyedvectors.Vocab at 0x13a4f8ed0>,
#  'deny': <gensim.models.keyedvectors.Vocab at 0x13a4f8f10>,
#  'someone’s': <gensim.models.keyedvectors.Vocab at 0x13a4f8f50>,
#  'credit': <gensim.models.keyedvectors.Vocab at 0x13a4f8f90>,
#  'application': <gensim.models.keyedvectors.Vocab at 0x13a4f8fd0>,
#  'use': <gensim.models.keyedvectors.Vocab at 0x13a4fa050>,
#  'case': <gensim.models.keyedvectors.Vocab at 0x13a4fa090>,
#  'determine': <gensim.models.keyedvectors.Vocab at 0x13a4fa0d0>,
#  'stringent': <gensim.models.keyedvectors.Vocab at 0x13a4fa110>,
#  'requirements': <gensim.models.keyedvectors.Vocab at 0x13a4fa150>,
#  'instance': <gensim.models.keyedvectors.Vocab at 0x13a4fa190>,
#  'suggesting': <gensim.models.keyedvectors.Vocab at 0x13a4fa1d0>,
#  'things': <gensim.models.keyedvectors.Vocab at 0x13a4fa210>,
#  'wildly': <gensim.models.keyedvectors.Vocab at 0x13a4fa250>,
#  'different': <gensim.models.keyedvectors.Vocab at 0x13a4fa290>,
#  'compared': <gensim.models.keyedvectors.Vocab at 0x13a4fa2d0>,
#  'algorithm': <gensim.models.keyedvectors.Vocab at 0x13a4fa310>,
#  'designed': <gensim.models.keyedvectors.Vocab at 0x13a4fa350>,
#  'make': <gensim.models.keyedvectors.Vocab at 0x13a4fa390>,
#  'decisions': <gensim.models.keyedvectors.Vocab at 0x13a4fa3d0>,
#  'autonomous': <gensim.models.keyedvectors.Vocab at 0x13a4fa410>,
#  'driving': <gensim.models.keyedvectors.Vocab at 0x13a4fa450>,
#  'space': <gensim.models.keyedvectors.Vocab at 0x13a4fa490>,
#  'example': <gensim.models.keyedvectors.Vocab at 0x13a4fa4d0>,
#  'illustrated': <gensim.models.keyedvectors.Vocab at 0x13a4fa510>,
#  'dilemma': <gensim.models.keyedvectors.Vocab at 0x13a4fa550>,
#  'six': <gensim.models.keyedvectors.Vocab at 0x13a4fa590>,
#  'levels': <gensim.models.keyedvectors.Vocab at 0x13a4fa5d0>,
#  'autonomy': <gensim.models.keyedvectors.Vocab at 0x13a4fa610>,
#  'might': <gensim.models.keyedvectors.Vocab at 0x13a4fa650>,
#  'imagine': <gensim.models.keyedvectors.Vocab at 0x13a4fa690>,
#  'subsequent': <gensim.models.keyedvectors.Vocab at 0x13a4fa6d0>,
#  'level': <gensim.models.keyedvectors.Vocab at 0x13a4fa710>,
#  'would': <gensim.models.keyedvectors.Vocab at 0x13a4fa750>,
#  'stricter': <gensim.models.keyedvectors.Vocab at 0x13a4fa790>,
#  'vehicle': <gensim.models.keyedvectors.Vocab at 0x13a4fa7d0>,
#  'explained': <gensim.models.keyedvectors.Vocab at 0x13a4fa810>,
#  'depending': <gensim.models.keyedvectors.Vocab at 0x13a4fa850>,
#  'type': <gensim.models.keyedvectors.Vocab at 0x13a4fa890>,
#  'may': <gensim.models.keyedvectors.Vocab at 0x13a4fa8d0>,
#  'able': <gensim.models.keyedvectors.Vocab at 0x13a4fa910>,
#  'away': <gensim.models.keyedvectors.Vocab at 0x13a4fa950>,
#  'potentially': <gensim.models.keyedvectors.Vocab at 0x13a4fa990>,
#  'need': <gensim.models.keyedvectors.Vocab at 0x13a4fa9d0>,
#  'roll': <gensim.models.keyedvectors.Vocab at 0x13a4faa10>,
#  'stages': <gensim.models.keyedvectors.Vocab at 0x13a4faa50>,
#  'require': <gensim.models.keyedvectors.Vocab at 0x13a4faa90>,
#  'thresholds': <gensim.models.keyedvectors.Vocab at 0x13a4faad0>,
#  'appropriate': <gensim.models.keyedvectors.Vocab at 0x13a4fab10>,
#  'basis': <gensim.models.keyedvectors.Vocab at 0x13a4fab50>,
#  'strive': <gensim.models.keyedvectors.Vocab at 0x13a4fab90>,
#  'metric': <gensim.models.keyedvectors.Vocab at 0x13a4fabd0>,
#  'combination': <gensim.models.keyedvectors.Vocab at 0x13a4fac10>,
#  'metrics': <gensim.models.keyedvectors.Vocab at 0x13a4fac50>,
#  'decides': <gensim.models.keyedvectors.Vocab at 0x13a4fac90>,
#  'whether': <gensim.models.keyedvectors.Vocab at 0x13a4facd0>,
#  'depends': <gensim.models.keyedvectors.Vocab at 0x13a4fad10>,
#  'accuracy': <gensim.models.keyedvectors.Vocab at 0x13a4fad50>,
#  'vital': <gensim.models.keyedvectors.Vocab at 0x13a4fad90>,
#  'often': <gensim.models.keyedvectors.Vocab at 0x13a4fadd0>,
#  'talked': <gensim.models.keyedvectors.Vocab at 0x13a4fae10>,
#  'without': <gensim.models.keyedvectors.Vocab at 0x13a4fae50>,
#  'accurate': <gensim.models.keyedvectors.Vocab at 0x13a4fae90>,
#  'predictions': <gensim.models.keyedvectors.Vocab at 0x13a4faed0>,
#  'purpose': <gensim.models.keyedvectors.Vocab at 0x13a4faf10>,
#  'deploying': <gensim.models.keyedvectors.Vocab at 0x13a4faf50>,
#  'best': <gensim.models.keyedvectors.Vocab at 0x13a4faf90>,
#  'within': <gensim.models.keyedvectors.Vocab at 0x13a4fafd0>,
#  'reasonable': <gensim.models.keyedvectors.Vocab at 0x13a4fd050>,
#  'limitations': <gensim.models.keyedvectors.Vocab at 0x13a4fd090>,
#  'however': <gensim.models.keyedvectors.Vocab at 0x13a4fd0d0>,
#  'direct': <gensim.models.keyedvectors.Vocab at 0x13a4fd110>,
#  'test': <gensim.models.keyedvectors.Vocab at 0x13a4fd150>,
#  'even': <gensim.models.keyedvectors.Vocab at 0x13a4fd190>,
#  'important': <gensim.models.keyedvectors.Vocab at 0x13a4fd1d0>,
#  'let': <gensim.models.keyedvectors.Vocab at 0x13a4fd210>,
#  'someone': <gensim.models.keyedvectors.Vocab at 0x13a4fd250>,
#  'needs': <gensim.models.keyedvectors.Vocab at 0x13a4fd290>,
#  'surgery': <gensim.models.keyedvectors.Vocab at 0x13a4fd2d0>,
#  'problem': <gensim.models.keyedvectors.Vocab at 0x13a4fd310>,
#  'operate': <gensim.models.keyedvectors.Vocab at 0x13a4fd350>,
#  'sick': <gensim.models.keyedvectors.Vocab at 0x13a4fd390>,
#  'people': <gensim.models.keyedvectors.Vocab at 0x13a4fd3d0>,
#  'could': <gensim.models.keyedvectors.Vocab at 0x13a4fd410>,
#  'consider': <gensim.models.keyedvectors.Vocab at 0x13a4fd450>,
#  'operating': <gensim.models.keyedvectors.Vocab at 0x13a4fd490>,
#  'healthy': <gensim.models.keyedvectors.Vocab at 0x13a4fd4d0>,
#  'patient': <gensim.models.keyedvectors.Vocab at 0x13a4fd510>,
#  'much': <gensim.models.keyedvectors.Vocab at 0x13a4fd550>,
#  'significant': <gensim.models.keyedvectors.Vocab at 0x13a4fd590>,
#  'mistake': <gensim.models.keyedvectors.Vocab at 0x13a4fd5d0>,
#  'cases': <gensim.models.keyedvectors.Vocab at 0x13a4fd610>,
#  'like': <gensim.models.keyedvectors.Vocab at 0x13a4fd650>,
#  'false': <gensim.models.keyedvectors.Vocab at 0x13a4fd690>,
#  'positives': <gensim.models.keyedvectors.Vocab at 0x13a4fd6d0>,
#  'dangerous': <gensim.models.keyedvectors.Vocab at 0x13a4fd710>,
#  'precision': <gensim.models.keyedvectors.Vocab at 0x13a4fd750>,
#  'recall': <gensim.models.keyedvectors.Vocab at 0x13a4fd790>,
#  'score': <gensim.models.keyedvectors.Vocab at 0x13a4fd7d0>,
#  'keep': <gensim.models.keyedvectors.Vocab at 0x13a4fd810>,
#  'simple': <gensim.models.keyedvectors.Vocab at 0x13a4fd850>,
#  'article': <gensim.models.keyedvectors.Vocab at 0x13a4fd890>,
#  'let’s': <gensim.models.keyedvectors.Vocab at 0x13a4fd8d0>,
#  'focus': <gensim.models.keyedvectors.Vocab at 0x13a4fd910>,
#  'practical': <gensim.models.keyedvectors.Vocab at 0x13a4fd950>,
#  'terms': <gensim.models.keyedvectors.Vocab at 0x13a4fd990>,
#  'you’ll': <gensim.models.keyedvectors.Vocab at 0x13a4fd9d0>,
#  'confirming': <gensim.models.keyedvectors.Vocab at 0x13a4fda10>,
#  'two': <gensim.models.keyedvectors.Vocab at 0x13a4fda50>,
#  'phases': <gensim.models.keyedvectors.Vocab at 0x13a4fda90>,
#  'training': <gensim.models.keyedvectors.Vocab at 0x13a4fdad0>,
#  'phase': <gensim.models.keyedvectors.Vocab at 0x13a4fdb10>,
#  'separate': <gensim.models.keyedvectors.Vocab at 0x13a4fdb50>,
#  'testing': <gensim.models.keyedvectors.Vocab at 0x13a4fdb90>,
#  'evaluate': <gensim.models.keyedvectors.Vocab at 0x13a4fdbd0>,
#  'generally': <gensim.models.keyedvectors.Vocab at 0x13a4fdc10>,
#  'aside': <gensim.models.keyedvectors.Vocab at 0x13a4fdc50>,
#  'portion': <gensim.models.keyedvectors.Vocab at 0x13a4fdc90>,
#  'data': <gensim.models.keyedvectors.Vocab at 0x13a4fdcd0>,
#  'validation': <gensim.models.keyedvectors.Vocab at 0x13a4fdd10>,
#  'validate': <gensim.models.keyedvectors.Vocab at 0x13a4fdd50>,
#  'trained': <gensim.models.keyedvectors.Vocab at 0x13a4fdd90>,
#  'used': <gensim.models.keyedvectors.Vocab at 0x13a4fddd0>,
#  'several': <gensim.models.keyedvectors.Vocab at 0x13a4fde10>,
#  'times': <gensim.models.keyedvectors.Vocab at 0x13a4fde50>,
#  'find': <gensim.models.keyedvectors.Vocab at 0x13a4fde90>,
#  'optimal': <gensim.models.keyedvectors.Vocab at 0x13a4fded0>,
#  'hyperparameters': <gensim.models.keyedvectors.Vocab at 0x13a4fdf10>,
#  'michael': <gensim.models.keyedvectors.Vocab at 0x13a4fdf50>,
#  'mccourt': <gensim.models.keyedvectors.Vocab at 0x13a4fdf90>,
#  'sigopt': <gensim.models.keyedvectors.Vocab at 0x13a4fdfd0>,
#  'wrote': <gensim.models.keyedvectors.Vocab at 0x13a4ff050>,
#  'split': <gensim.models.keyedvectors.Vocab at 0x13a4ff090>,
#  'mlops': <gensim.models.keyedvectors.Vocab at 0x13a4ff0d0>,
#  'get': <gensim.models.keyedvectors.Vocab at 0x13a4ff110>,
#  'model’s': <gensim.models.keyedvectors.Vocab at 0x13a4ff150>,
#  'using': <gensim.models.keyedvectors.Vocab at 0x13a4ff190>,
#  'hasn’t': <gensim.models.keyedvectors.Vocab at 0x13a4ff1d0>,
#  'iterations': <gensim.models.keyedvectors.Vocab at 0x13a4ff210>,
#  'generalize': <gensim.models.keyedvectors.Vocab at 0x13a4ff250>,
#  'words': <gensim.models.keyedvectors.Vocab at 0x13a4ff290>,
#  'produce': <gensim.models.keyedvectors.Vocab at 0x13a4ff2d0>,
#  'memorized': <gensim.models.keyedvectors.Vocab at 0x13a4ff310>,
#  'answers': <gensim.models.keyedvectors.Vocab at 0x13a4ff350>,
#  'term': <gensim.models.keyedvectors.Vocab at 0x13a4ff390>,
#  'overfitting': <gensim.models.keyedvectors.Vocab at 0x13a4ff3d0>,
#  'performs': <gensim.models.keyedvectors.Vocab at 0x13a4ff410>,
#  'well': <gensim.models.keyedvectors.Vocab at 0x13a4ff450>,
#  'fails': <gensim.models.keyedvectors.Vocab at 0x13a4ff490>,
#  'cassie': <gensim.models.keyedvectors.Vocab at 0x13a4ff4d0>,
#  'kozyrkov': <gensim.models.keyedvectors.Vocab at 0x13a4ff510>,
#  'google': <gensim.models.keyedvectors.Vocab at 0x13a4ff550>,
#  'done': <gensim.models.keyedvectors.Vocab at 0x13a4ff590>,
#  'fantastic': <gensim.models.keyedvectors.Vocab at 0x13a4ff5d0>,
#  'short': <gensim.models.keyedvectors.Vocab at 0x13a4ff610>,
#  'explainer': <gensim.models.keyedvectors.Vocab at 0x13a4ff650>,
#  'validating': <gensim.models.keyedvectors.Vocab at 0x13a4ff690>,
#  'codify': <gensim.models.keyedvectors.Vocab at 0x13a4ff6d0>,
#  'engineering': <gensim.models.keyedvectors.Vocab at 0x13a4ff710>,
#  'perspective': <gensim.models.keyedvectors.Vocab at 0x13a4ff750>,
#  'criteria': <gensim.models.keyedvectors.Vocab at 0x13a4ff790>,
#  'making': <gensim.models.keyedvectors.Vocab at 0x13a4ff7d0>,
#  'sure': <gensim.models.keyedvectors.Vocab at 0x13a4ff810>,
#  'codified': <gensim.models.keyedvectors.Vocab at 0x13a4ff850>,
#  'pipeline': <gensim.models.keyedvectors.Vocab at 0x13a4ff890>,
#  'written': <gensim.models.keyedvectors.Vocab at 0x13a4ff8d0>,
#  'baselines': <gensim.models.keyedvectors.Vocab at 0x13a4ff910>,
#  'adhered': <gensim.models.keyedvectors.Vocab at 0x13a4ff950>,
#  'newly': <gensim.models.keyedvectors.Vocab at 0x13a4ff990>,
#  'deployed': <gensim.models.keyedvectors.Vocab at 0x13a4ff9d0>,
#  'serve': <gensim.models.keyedvectors.Vocab at 0x13a4ffa10>,
#  'benchmark': <gensim.models.keyedvectors.Vocab at 0x13a4ffa50>,
#  'future': <gensim.models.keyedvectors.Vocab at 0x13a4ffa90>,
#  'always': <gensim.models.keyedvectors.Vocab at 0x13a4ffad0>,
#  'compare': <gensim.models.keyedvectors.Vocab at 0x13a4ffb10>,
#  'similarly': <gensim.models.keyedvectors.Vocab at 0x13a4ffb50>,
#  'perform': <gensim.models.keyedvectors.Vocab at 0x13a4ffb90>,
#  'part': <gensim.models.keyedvectors.Vocab at 0x13a4ffbd0>,
#  'rather': <gensim.models.keyedvectors.Vocab at 0x13a4ffc10>,
#  'manual': <gensim.models.keyedvectors.Vocab at 0x13a4ffc50>,
#  'process': <gensim.models.keyedvectors.Vocab at 0x13a4ffc90>,
#  'script': <gensim.models.keyedvectors.Vocab at 0x13a4ffcd0>,
#  'setting': <gensim.models.keyedvectors.Vocab at 0x13a4ffd10>,
#  'train': <gensim.models.keyedvectors.Vocab at 0x13a4ffd50>,
#  'build': <gensim.models.keyedvectors.Vocab at 0x13a4ffd90>,
#  'system': <gensim.models.keyedvectors.Vocab at 0x13a4ffdd0>,
#  'continuously': <gensim.models.keyedvectors.Vocab at 0x13a4ffe10>,
#  'retrain': <gensim.models.keyedvectors.Vocab at 0x13a4ffe50>,
#  'maintain': <gensim.models.keyedvectors.Vocab at 0x13a4ffe90>,
#  'product': <gensim.models.keyedvectors.Vocab at 0x13a4ffed0>,
#  'interested': <gensim.models.keyedvectors.Vocab at 0x13a4fff10>,
#  'pipelines': <gensim.models.keyedvectors.Vocab at 0x13a4fff50>,
#  'related': <gensim.models.keyedvectors.Vocab at 0x13a4fff90>,
#  'content': <gensim.models.keyedvectors.Vocab at 0x13a4fffd0>,
#  'originally': <gensim.models.keyedvectors.Vocab at 0x13a501050>,
#  'published': <gensim.models.keyedvectors.Vocab at 0x13a501090>,
#  'https': <gensim.models.keyedvectors.Vocab at 0x13a5010d0>,
#  'valohai': <gensim.models.keyedvectors.Vocab at 0x13a501110>,
#  'varying': <gensim.models.keyedvectors.Vocab at 0x13a501150>,
#  'patients': <gensim.models.keyedvectors.Vocab at 0x13a501190>,
#  'growing': <gensim.models.keyedvectors.Vocab at 0x13a5011d0>,
#  'better': <gensim.models.keyedvectors.Vocab at 0x13a501210>,
#  'management': <gensim.models.keyedvectors.Vocab at 0x13a501250>,
#  'healthcare': <gensim.models.keyedvectors.Vocab at 0x13a501290>,
#  'driven': <gensim.models.keyedvectors.Vocab at 0x13a5012d0>,
#  'companies': <gensim.models.keyedvectors.Vocab at 0x13a501310>,
#  'look': <gensim.models.keyedvectors.Vocab at 0x13a501350>,
#  'help': <gensim.models.keyedvectors.Vocab at 0x13a501390>,
#  'technology': <gensim.models.keyedvectors.Vocab at 0x13a5013d0>,
#  'suffice': <gensim.models.keyedvectors.Vocab at 0x13a501410>,
#  'say': <gensim.models.keyedvectors.Vocab at 0x13a501450>,
#  'answered': <gensim.models.keyedvectors.Vocab at 0x13a501490>,
#  'call': <gensim.models.keyedvectors.Vocab at 0x13a5014d0>,
#  'plenty': <gensim.models.keyedvectors.Vocab at 0x13a501510>,
#  'resources': <gensim.models.keyedvectors.Vocab at 0x13a501550>,
#  'offer': <gensim.models.keyedvectors.Vocab at 0x13a501590>,
#  'quality': <gensim.models.keyedvectors.Vocab at 0x13a5015d0>,
#  'none': <gensim.models.keyedvectors.Vocab at 0x13a501610>,
#  'proven': <gensim.models.keyedvectors.Vocab at 0x13a501650>,
#  'quite': <gensim.models.keyedvectors.Vocab at 0x13a501690>,
#  'potent': <gensim.models.keyedvectors.Vocab at 0x13a5016d0>,
#  'internet': <gensim.models.keyedvectors.Vocab at 0x13a501710>,
#  'essentially': <gensim.models.keyedvectors.Vocab at 0x139b8ae50>,
#  'network': <gensim.models.keyedvectors.Vocab at 0x13a4f1fd0>,
#  'devices': <gensim.models.keyedvectors.Vocab at 0x13a4f1b90>,
#  'connected': <gensim.models.keyedvectors.Vocab at 0x13a4f0190>,
#  'via': <gensim.models.keyedvectors.Vocab at 0x13a4f0710>,
#  'context': <gensim.models.keyedvectors.Vocab at 0x13a4f03d0>,
#  'empowers': <gensim.models.keyedvectors.Vocab at 0x13a4ef810>,
#  'providers': <gensim.models.keyedvectors.Vocab at 0x13a4efed0>,
#  'ability': <gensim.models.keyedvectors.Vocab at 0x13a4efb50>,
#  'utilize': <gensim.models.keyedvectors.Vocab at 0x13a4ef850>,
#  'gathered': <gensim.models.keyedvectors.Vocab at 0x13a4eec50>,
#  'sensors': <gensim.models.keyedvectors.Vocab at 0x13a4ecf90>,
#  'etc': <gensim.models.keyedvectors.Vocab at 0x13a4ec8d0>,
#  'achieve': <gensim.models.keyedvectors.Vocab at 0x13a4ebd10>,
#  'impactful': <gensim.models.keyedvectors.Vocab at 0x13601e150>,
#  'results': <gensim.models.keyedvectors.Vocab at 0x13601e5d0>,
#  'every': <gensim.models.keyedvectors.Vocab at 0x13601e050>,
#  'step': <gensim.models.keyedvectors.Vocab at 0x13601e550>,
#  'starting': <gensim.models.keyedvectors.Vocab at 0x135ea4f90>,
#  'early': <gensim.models.keyedvectors.Vocab at 0x136017ed0>,
#  'diagnosis': <gensim.models.keyedvectors.Vocab at 0x136017550>,
#  'remotely': <gensim.models.keyedvectors.Vocab at 0x136017590>,
#  'monitoring': <gensim.models.keyedvectors.Vocab at 0x136017a50>,
#  'patients’': <gensim.models.keyedvectors.Vocab at 0x136017ad0>,
#  'statistics': <gensim.models.keyedvectors.Vocab at 0x139ed5910>,
#  'iot': <gensim.models.keyedvectors.Vocab at 0x10e148b50>,
#  'encouraged': <gensim.models.keyedvectors.Vocab at 0x13a501750>,
#  'enabled': <gensim.models.keyedvectors.Vocab at 0x13a501790>,
#  'world': <gensim.models.keyedvectors.Vocab at 0x13a5017d0>,
#  'positive': <gensim.models.keyedvectors.Vocab at 0x13a501810>,
#  'change': <gensim.models.keyedvectors.Vocab at 0x13a501850>,
#  'sector': <gensim.models.keyedvectors.Vocab at 0x13a501890>,
#  'listed': <gensim.models.keyedvectors.Vocab at 0x13a5018d0>,
#  'understand': <gensim.models.keyedvectors.Vocab at 0x13a501910>,
#  'benefits': <gensim.models.keyedvectors.Vocab at 0x13a501950>,
#  'medicine': <gensim.models.keyedvectors.Vocab at 0x13a501990>,
#  'dose': <gensim.models.keyedvectors.Vocab at 0x13a5019d0>,
#  'doctor': <gensim.models.keyedvectors.Vocab at 0x13a501a10>,
#  'tell': <gensim.models.keyedvectors.Vocab at 0x13a501a50>,
#  'regular': <gensim.models.keyedvectors.Vocab at 0x13a501a90>,
#  'intake': <gensim.models.keyedvectors.Vocab at 0x13a501ad0>,
#  'underpins': <gensim.models.keyedvectors.Vocab at 0x13a501b10>,
#  'treatment': <gensim.models.keyedvectors.Vocab at 0x13a501b50>,
#  'plan': <gensim.models.keyedvectors.Vocab at 0x13a501b90>,
#  'effectiveness': <gensim.models.keyedvectors.Vocab at 0x13a501bd0>,
#  'way': <gensim.models.keyedvectors.Vocab at 0x13a501c10>,
#  'ensure': <gensim.models.keyedvectors.Vocab at 0x13a501c50>,
#  'don’t': <gensim.models.keyedvectors.Vocab at 0x13a501c90>,
#  'fall': <gensim.models.keyedvectors.Vocab at 0x13a501cd0>,
#  'behind': <gensim.models.keyedvectors.Vocab at 0x13a501d10>,
#  'proper': <gensim.models.keyedvectors.Vocab at 0x13a501d50>,
#  'prescribed': <gensim.models.keyedvectors.Vocab at 0x13a501d90>,
#  'tools': <gensim.models.keyedvectors.Vocab at 0x13a501dd0>,
#  'enable': <gensim.models.keyedvectors.Vocab at 0x13a501e10>,
#  'professionals': <gensim.models.keyedvectors.Vocab at 0x13a501e50>,
#  'regulate': <gensim.models.keyedvectors.Vocab at 0x13a501e90>,
#  'amount': <gensim.models.keyedvectors.Vocab at 0x13a501ed0>,
#  'eye': <gensim.models.keyedvectors.Vocab at 0x13a501f10>,
#  'efficacy': <gensim.models.keyedvectors.Vocab at 0x13a501f50>,
#  'miss': <gensim.models.keyedvectors.Vocab at 0x13a501f90>,
#  'reminder': <gensim.models.keyedvectors.Vocab at 0x13a501fd0>,
#  'sent': <gensim.models.keyedvectors.Vocab at 0x13a503050>,
#  'project': <gensim.models.keyedvectors.Vocab at 0x13a503090>,
#  'adjusted': <gensim.models.keyedvectors.Vocab at 0x13a5030d0>,
#  'automation': <gensim.models.keyedvectors.Vocab at 0x13a503110>,
#  'mentioned': <gensim.models.keyedvectors.Vocab at 0x13a503150>,
#  'elaborate': <gensim.models.keyedvectors.Vocab at 0x13a503190>,
#  'complicated': <gensim.models.keyedvectors.Vocab at 0x13a5031d0>,
#  'brimming': <gensim.models.keyedvectors.Vocab at 0x13a503210>,
#  'mundane': <gensim.models.keyedvectors.Vocab at 0x13a503250>,
#  'tasks': <gensim.models.keyedvectors.Vocab at 0x13a503290>,
#  'facilities': <gensim.models.keyedvectors.Vocab at 0x13a5032d0>,
#  'automate': <gensim.models.keyedvectors.Vocab at 0x13a503310>,
#  'daily': <gensim.models.keyedvectors.Vocab at 0x13a503350>,
#  'administrative': <gensim.models.keyedvectors.Vocab at 0x13a503390>,
#  'necessarily': <gensim.models.keyedvectors.Vocab at 0x13a5033d0>,
#  'human': <gensim.models.keyedvectors.Vocab at 0x13a503410>,
#  'intervention': <gensim.models.keyedvectors.Vocab at 0x13a503450>,
#  'plus': <gensim.models.keyedvectors.Vocab at 0x13a503490>,
#  'analyze': <gensim.models.keyedvectors.Vocab at 0x13a5034d0>,
#  'passes': <gensim.models.keyedvectors.Vocab at 0x13a503510>,
#  'systems': <gensim.models.keyedvectors.Vocab at 0x13a503550>,
#  'monitor': <gensim.models.keyedvectors.Vocab at 0x13a503590>,
#  'changes': <gensim.models.keyedvectors.Vocab at 0x13a5035d0>,
#  'health': <gensim.models.keyedvectors.Vocab at 0x13a503610>,
#  'reduced': <gensim.models.keyedvectors.Vocab at 0x13a503650>,
#  'costs': <gensim.models.keyedvectors.Vocab at 0x13a503690>,
#  'critical': <gensim.models.keyedvectors.Vocab at 0x13a5036d0>,
#  'unfortunate': <gensim.models.keyedvectors.Vocab at 0x13a503710>,
#  'truth': <gensim.models.keyedvectors.Vocab at 0x13a503750>,
#  'expensive': <gensim.models.keyedvectors.Vocab at 0x13a503790>,
#  'parties': <gensim.models.keyedvectors.Vocab at 0x13a5037d0>,
#  'equation': <gensim.models.keyedvectors.Vocab at 0x13a503810>,
#  'regard': <gensim.models.keyedvectors.Vocab at 0x13a503850>,
#  'allowing': <gensim.models.keyedvectors.Vocab at 0x13a503890>,
#  'consult': <gensim.models.keyedvectors.Vocab at 0x13a5038d0>,
#  'doctors': <gensim.models.keyedvectors.Vocab at 0x13a503910>,
#  'needing': <gensim.models.keyedvectors.Vocab at 0x13a503950>,
#  'travel': <gensim.models.keyedvectors.Vocab at 0x13a503990>,
#  'facility': <gensim.models.keyedvectors.Vocab at 0x13a5039d0>,
#  'helps': <gensim.models.keyedvectors.Vocab at 0x13a503a10>,
#  'streamline': <gensim.models.keyedvectors.Vocab at 0x13a503a50>,
#  'databases': <gensim.models.keyedvectors.Vocab at 0x13a503a90>,
#  'long': <gensim.models.keyedvectors.Vocab at 0x13a503ad0>,
#  'cutting': <gensim.models.keyedvectors.Vocab at 0x13a503b10>,
#  'hospitals': <gensim.models.keyedvectors.Vocab at 0x13a503b50>,
#  'great': <gensim.models.keyedvectors.Vocab at 0x13a503b90>,
#  'must': <gensim.models.keyedvectors.Vocab at 0x13a503bd0>,
#  'dive': <gensim.models.keyedvectors.Vocab at 0x13a503c10>,
#  'headfirst': <gensim.models.keyedvectors.Vocab at 0x13a503c50>,
#  'first': <gensim.models.keyedvectors.Vocab at 0x13a503c90>,
#  'taking': <gensim.models.keyedvectors.Vocab at 0x13a503cd0>,
#  'time': <gensim.models.keyedvectors.Vocab at 0x13a503d10>,
#  'acquaint': <gensim.models.keyedvectors.Vocab at 0x13a503d50>,
#  'challenges': <gensim.models.keyedvectors.Vocab at 0x13a503d90>,
#  'security': <gensim.models.keyedvectors.Vocab at 0x13a503dd0>,
#  'abundance': <gensim.models.keyedvectors.Vocab at 0x13a503e10>,
#  'sensitive': <gensim.models.keyedvectors.Vocab at 0x13a503e50>,
#  'involved': <gensim.models.keyedvectors.Vocab at 0x13a503e90>,
#  'translating': <gensim.models.keyedvectors.Vocab at 0x13a503ed0>,
#  'risks': <gensim.models.keyedvectors.Vocab at 0x13a503f10>,
#  'integration': <gensim.models.keyedvectors.Vocab at 0x13a503f50>,
#  'since': <gensim.models.keyedvectors.Vocab at 0x13a503f90>,
#  'entire': <gensim.models.keyedvectors.Vocab at 0x13a503fd0>,
#  'concept': <gensim.models.keyedvectors.Vocab at 0x13a506050>,
#  'underpinned': <gensim.models.keyedvectors.Vocab at 0x13a506090>,
#  'idea': <gensim.models.keyedvectors.Vocab at 0x13a5060d0>,
#  'denying': <gensim.models.keyedvectors.Vocab at 0x13a506110>,
#  'suppose': <gensim.models.keyedvectors.Vocab at 0x13a506150>,
#  'genuinely': <gensim.models.keyedvectors.Vocab at 0x13a506190>,
#  'leverage': <gensim.models.keyedvectors.Vocab at 0x13a5061d0>,
#  'potential': <gensim.models.keyedvectors.Vocab at 0x13a506210>,
#  'recommend': <gensim.models.keyedvectors.Vocab at 0x13a506250>,
#  'carefully': <gensim.models.keyedvectors.Vocab at 0x13a506290>,
#  'strategizing': <gensim.models.keyedvectors.Vocab at 0x13a5062d0>,
#  'development': <gensim.models.keyedvectors.Vocab at 0x13a506310>,
#  'software': <gensim.models.keyedvectors.Vocab at 0x13a506350>,
#  'solution': <gensim.models.keyedvectors.Vocab at 0x13a506390>,
#  'overcome': <gensim.models.keyedvectors.Vocab at 0x13a5063d0>,
#  'associated': <gensim.models.keyedvectors.Vocab at 0x13a506410>,
#  'ones': <gensim.models.keyedvectors.Vocab at 0x13a506450>,
#  'welcome': <gensim.models.keyedvectors.Vocab at 0x13a506490>,
#  'dsc': <gensim.models.keyedvectors.Vocab at 0x13a5064d0>,
#  'weekly': <gensim.models.keyedvectors.Vocab at 0x13a506510>,
#  'digest': <gensim.models.keyedvectors.Vocab at 0x13a506550>,
#  'science': <gensim.models.keyedvectors.Vocab at 0x13a506590>,
#  'central': <gensim.models.keyedvectors.Vocab at 0x13a5065d0>,
#  'week': <gensim.models.keyedvectors.Vocab at 0x13a506610>,
#  'pick': <gensim.models.keyedvectors.Vocab at 0x13a506650>,
#  'newest': <gensim.models.keyedvectors.Vocab at 0x13a506690>,
#  'brightest': <gensim.models.keyedvectors.Vocab at 0x13a5066d0>,
#  'articles': <gensim.models.keyedvectors.Vocab at 0x13a506710>,
#  'topic': <gensim.models.keyedvectors.Vocab at 0x13a506750>,
#  'informs': <gensim.models.keyedvectors.Vocab at 0x13a506790>,
#  'lives': <gensim.models.keyedvectors.Vocab at 0x13a5067d0>,
#  'powers': <gensim.models.keyedvectors.Vocab at 0x13a506810>,
#  'provides': <gensim.models.keyedvectors.Vocab at 0x13a506850>,
#  'insights': <gensim.models.keyedvectors.Vocab at 0x13a506890>,
#  'editor': <gensim.models.keyedvectors.Vocab at 0x13a5068d0>,
#  'desk': <gensim.models.keyedvectors.Vocab at 0x13a506910>,
#  'creation': <gensim.models.keyedvectors.Vocab at 0x13a506950>,
#  'assets': <gensim.models.keyedvectors.Vocab at 0x13a506990>,
#  'remember': <gensim.models.keyedvectors.Vocab at 0x13a5069d0>,
#  'happens': <gensim.models.keyedvectors.Vocab at 0x13a506a10>,
#  'stored': <gensim.models.keyedvectors.Vocab at 0x13a506a50>,
#  'certain': <gensim.models.keyedvectors.Vocab at 0x13a506a90>,
#  'theory': <gensim.models.keyedvectors.Vocab at 0x13a506ad0>,
#  'created': <gensim.models.keyedvectors.Vocab at 0x13a506b10>,
#  'fairly': <gensim.models.keyedvectors.Vocab at 0x13a506b50>,
#  'deep': <gensim.models.keyedvectors.Vocab at 0x13a506b90>,
#  'understanding': <gensim.models.keyedvectors.Vocab at 0x13a506bd0>,
#  'modeling': <gensim.models.keyedvectors.Vocab at 0x13a506c10>,
#  'design': <gensim.models.keyedvectors.Vocab at 0x13a506c50>,
#  'practice': <gensim.models.keyedvectors.Vocab at 0x13a506c90>,
#  'programmers': <gensim.models.keyedvectors.Vocab at 0x13a506cd0>,
#  'optimized': <gensim.models.keyedvectors.Vocab at 0x13a506d10>,
#  'particular': <gensim.models.keyedvectors.Vocab at 0x13a506d50>,
#  'actually': <gensim.models.keyedvectors.Vocab at 0x13a506d90>,
#  'lot': <gensim.models.keyedvectors.Vocab at 0x13a506dd0>,
#  'got': <gensim.models.keyedvectors.Vocab at 0x13a506e10>,
#  'ancient': <gensim.models.keyedvectors.Vocab at 0x13a506e50>,
#  'legacy': <gensim.models.keyedvectors.Vocab at 0x13a506e90>,
#  'takes': <gensim.models.keyedvectors.Vocab at 0x13a506ed0>,
#  'brings': <gensim.models.keyedvectors.Vocab at 0x13a506f10>,
#  'value': <gensim.models.keyedvectors.Vocab at 0x13a506f50>,
#  'cardinality': <gensim.models.keyedvectors.Vocab at 0x13a506f90>,
#  'properly': <gensim.models.keyedvectors.Vocab at 0x13a506fd0>,
#  'captured': <gensim.models.keyedvectors.Vocab at 0x13a509050>,
#  'managed': <gensim.models.keyedvectors.Vocab at 0x13a509090>,
#  'dimensions': <gensim.models.keyedvectors.Vocab at 0x13a5090d0>,
#  'maintained': <gensim.models.keyedvectors.Vocab at 0x13a509110>,
#  'consistent': <gensim.models.keyedvectors.Vocab at 0x13a509150>,
#  'reality': <gensim.models.keyedvectors.Vocab at 0x13a509190>,
#  'work': <gensim.models.keyedvectors.Vocab at 0x13a5091d0>,
#  'getting': <gensim.models.keyedvectors.Vocab at 0x13a509210>,
#  'compute': <gensim.models.keyedvectors.Vocab at 0x13a509250>,
#  'cycles': <gensim.models.keyedvectors.Vocab at 0x13a509290>,
#  'seem': <gensim.models.keyedvectors.Vocab at 0x13a5092d0>,
#  'easier': <gensim.models.keyedvectors.Vocab at 0x13a509310>,
#  'machines': <gensim.models.keyedvectors.Vocab at 0x13a509350>,
#  'handle': <gensim.models.keyedvectors.Vocab at 0x13a509390>,
#  'comprehensible': <gensim.models.keyedvectors.Vocab at 0x13a5093d0>,
#  'matters': <gensim.models.keyedvectors.Vocab at 0x13a509410>,
#  'selection': <gensim.models.keyedvectors.Vocab at 0x13a509450>,
#  'informative': <gensim.models.keyedvectors.Vocab at 0x13a509490>,
#  'provoking': <gensim.models.keyedvectors.Vocab at 0x13a5094d0>,
#  'writing': <gensim.models.keyedvectors.Vocab at 0x13a509510>,
#  'check': <gensim.models.keyedvectors.Vocab at 0x13a509550>,
#  'guidelines': <gensim.models.keyedvectors.Vocab at 0x13a509590>,
#  'know': <gensim.models.keyedvectors.Vocab at 0x13a5095d0>,
#  'think': <gensim.models.keyedvectors.Vocab at 0x13a509610>,
#  'featured': <gensim.models.keyedvectors.Vocab at 0x13a509650>,
#  'collection': <gensim.models.keyedvectors.Vocab at 0x13a509690>,
#  'text': <gensim.models.keyedvectors.Vocab at 0x13a5096d0>,
#  'interpretation': <gensim.models.keyedvectors.Vocab at 0x13a509710>,
#  'manager': <gensim.models.keyedvectors.Vocab at 0x13a509750>,
#  'key': <gensim.models.keyedvectors.Vocab at 0x13a509790>,
#  'success': <gensim.models.keyedvectors.Vocab at 0x13a5097d0>,
#  'predicting': <gensim.models.keyedvectors.Vocab at 0x13a509810>,
#  'heart': <gensim.models.keyedvectors.Vocab at 0x13a509850>,
#  'disease': <gensim.models.keyedvectors.Vocab at 0x13a509890>,
#  'independent': <gensim.models.keyedvectors.Vocab at 0x13a5098d0>,
#  'variables': <gensim.models.keyedvectors.Vocab at 0x13a509910>,
#  'include': <gensim.models.keyedvectors.Vocab at 0x13a509950>,
#  'regressi': <gensim.models.keyedvectors.Vocab at 0x13a509990>,
#  'ssl': <gensim.models.keyedvectors.Vocab at 0x13a5099d0>,
#  'certificates': <gensim.models.keyedvectors.Vocab at 0x13a509a10>,
#  'phishers': <gensim.models.keyedvectors.Vocab at 0x13a509a50>,
#  'what’s': <gensim.models.keyedvectors.Vocab at 0x13a509a90>,
#  'professions': <gensim.models.keyedvectors.Vocab at 0x13a509ad0>,
#  'scientists': <gensim.models.keyedvectors.Vocab at 0x13a509b10>,
#  'leveraging': <gensim.models.keyedvectors.Vocab at 0x13a509b50>,
#  'everything': <gensim.models.keyedvectors.Vocab at 0x13a509b90>,
#  'generative': <gensim.models.keyedvectors.Vocab at 0x13a509bd0>,
#  'adversarial': <gensim.models.keyedvectors.Vocab at 0x13a509c10>,
#  'networks': <gensim.models.keyedvectors.Vocab at 0x13a509c50>,
#  'depth': <gensim.models.keyedvectors.Vocab at 0x13a509c90>,
#  'devops': <gensim.models.keyedvectors.Vocab at 0x13a509cd0>,
#  'developers': <gensim.models.keyedvectors.Vocab at 0x13a509d10>,
#  'interesting': <gensim.models.keyedvectors.Vocab at 0x13a509d50>,
#  'poisson': <gensim.models.keyedvectors.Vocab at 0x13a509d90>,
#  'binomial': <gensim.models.keyedvectors.Vocab at 0x13a509dd0>,
#  'distribution': <gensim.models.keyedvectors.Vocab at 0x13a509e10>,
#  'covariance': <gensim.models.keyedvectors.Vocab at 0x13a509e50>,
#  'correlation': <gensim.models.keyedvectors.Vocab at 0x13a509e90>,
#  'digital': <gensim.models.keyedvectors.Vocab at 0x13a509ed0>,
#  'robber': <gensim.models.keyedvectors.Vocab at 0x13a509f10>,
#  'barons': <gensim.models.keyedvectors.Vocab at 0x13a509f50>,
#  'vertical': <gensim.models.keyedvectors.Vocab at 0x13a509f90>,
#  'university': <gensim.models.keyedvectors.Vocab at 0x13a509fd0>,
#  'rwanda': <gensim.models.keyedvectors.Vocab at 0x13a50b050>,
#  'institution': <gensim.models.keyedvectors.Vocab at 0x13a50b090>,
#  'africa': <gensim.models.keyedvectors.Vocab at 0x13a50b0d0>,
#  'join': <gensim.models.keyedvectors.Vocab at 0x13a50b110>,
#  'significance': <gensim.models.keyedvectors.Vocab at 0x13a50b150>,
#  'probability': <gensim.models.keyedvectors.Vocab at 0x13a50b190>,
#  'mass': <gensim.models.keyedvectors.Vocab at 0x13a50b1d0>,
#  'function': <gensim.models.keyedvectors.Vocab at 0x13a50b210>,
#  'density': <gensim.models.keyedvectors.Vocab at 0x13a50b250>,
#  'three': <gensim.models.keyedvectors.Vocab at 0x13a50b290>,
#  'steps': <gensim.models.keyedvectors.Vocab at 0x13a50b2d0>,
#  'conquering': <gensim.models.keyedvectors.Vocab at 0x13a50b310>,
#  'last': <gensim.models.keyedvectors.Vocab at 0x13a50b350>,
#  'mile': <gensim.models.keyedvectors.Vocab at 0x13a50b390>,
#  'analytics': <gensim.models.keyedvectors.Vocab at 0x13a50b3d0>,
#  'public': <gensim.models.keyedvectors.Vocab at 0x13a50b410>,
#  'cloud': <gensim.models.keyedvectors.Vocab at 0x13a50b450>,
#  'indispensable': <gensim.models.keyedvectors.Vocab at 0x13a50b490>,
#  'component': <gensim.models.keyedvectors.Vocab at 0x13a50b4d0>,
#  'businesses': <gensim.models.keyedvectors.Vocab at 0x13a50b510>,
#  'tech': <gensim.models.keyedvectors.Vocab at 0x13a50b550>,
#  'target': <gensim.models.keyedvectors.Vocab at 0x13a50b590>,
#  'brain': <gensim.models.keyedvectors.Vocab at 0x13a50b5d0>,
#  'teasers': <gensim.models.keyedvectors.Vocab at 0x13a50b610>,
#  'fun': <gensim.models.keyedvectors.Vocab at 0x13a50b650>,
#  'tips': <gensim.models.keyedvectors.Vocab at 0x13a50b690>,
#  'python': <gensim.models.keyedvectors.Vocab at 0x13a50b6d0>,
#  'presidential': <gensim.models.keyedvectors.Vocab at 0x13a50b710>,
#  'polling': <gensim.models.keyedvectors.Vocab at 0x13a50b750>,
#  'misses': <gensim.models.keyedvectors.Vocab at 0x13a50b790>,
#  'mark': <gensim.models.keyedvectors.Vocab at 0x13a50b7d0>,
#  '2020': <gensim.models.keyedvectors.Vocab at 0x13a50b810>,
#  'infosys': <gensim.models.keyedvectors.Vocab at 0x13a50b850>,
#  'launches': <gensim.models.keyedvectors.Vocab at 0x13a50b890>,
#  'applied': <gensim.models.keyedvectors.Vocab at 0x13a50b8d0>,
#  'enterprises': <gensim.models.keyedvectors.Vocab at 0x13a50b910>,
#  'rights': <gensim.models.keyedvectors.Vocab at 0x13a50b950>,
#  'pay': <gensim.models.keyedvectors.Vocab at 0x13a50b990>,
#  'taxes': <gensim.models.keyedvectors.Vocab at 0x13a50b9d0>,
#  'days': <gensim.models.keyedvectors.Vocab at 0x13a50ba10>,
#  'twins': <gensim.models.keyedvectors.Vocab at 0x13a50ba50>,
#  'supply': <gensim.models.keyedvectors.Vocab at 0x13a50ba90>,
#  'chain': <gensim.models.keyedvectors.Vocab at 0x13a50bad0>,
#  'picture': <gensim.models.keyedvectors.Vocab at 0x13a50bb10>,
#  'source': <gensim.models.keyedvectors.Vocab at 0x13a50bb50>,
#  'emails': <gensim.models.keyedvectors.Vocab at 0x13a50bb90>,
#  'please': <gensim.models.keyedvectors.Vocab at 0x13a50bbd0>,
#  'add': <gensim.models.keyedvectors.Vocab at 0x13a50bc10>,
#  'email': <gensim.models.keyedvectors.Vocab at 0x13a50bc50>,
#  'protected': <gensim.models.keyedvectors.Vocab at 0x13a50bc90>,
#  'address': <gensim.models.keyedvectors.Vocab at 0x13a50bcd0>,
#  'book': <gensim.models.keyedvectors.Vocab at 0x13a50bd10>,
#  'whitelist': <gensim.models.keyedvectors.Vocab at 0x13a50bd50>,
#  'subscribe': <gensim.models.keyedvectors.Vocab at 0x13a50bd90>,
#  'newsletter': <gensim.models.keyedvectors.Vocab at 0x13a50bdd0>,
#  'comprehensive': <gensim.models.keyedvectors.Vocab at 0x13a50be10>,
#  'repository': <gensim.models.keyedvectors.Vocab at 0x13a50be50>,
#  'videos': <gensim.models.keyedvectors.Vocab at 0x13a50be90>,
#  'search': <gensim.models.keyedvectors.Vocab at 0x13a50bed0>,
#  'post': <gensim.models.keyedvectors.Vocab at 0x13a50bf10>,
#  'blog': <gensim.models.keyedvectors.Vocab at 0x13a50bf50>,
#  'ask': <gensim.models.keyedvectors.Vocab at 0x13a50bf90>,
#  'follow': <gensim.models.keyedvectors.Vocab at 0x13a50bfd0>,
#  'twitter': <gensim.models.keyedvectors.Vocab at 0x13a50e050>,
#  'datasciencectrl': <gensim.models.keyedvectors.Vocab at 0x13a50e090>,
#  'analyticbridge': <gensim.models.keyedvectors.Vocab at 0x13a50e0d0>,
#  'meet': <gensim.models.keyedvectors.Vocab at 0x13a50e110>,
#  'mining': <gensim.models.keyedvectors.Vocab at 0x13a50e150>,
#  'experts': <gensim.models.keyedvectors.Vocab at 0x13a50e190>,
#  'today’s': <gensim.models.keyedvectors.Vocab at 0x13a50e1d0>,
#  'interview': <gensim.models.keyedvectors.Vocab at 0x13a50e210>,
#  'explores': <gensim.models.keyedvectors.Vocab at 0x13a50e250>,
#  'common': <gensim.models.keyedvectors.Vocab at 0x13a50e290>,
#  'issues': <gensim.models.keyedvectors.Vocab at 0x13a50e2d0>,
#  'faced': <gensim.models.keyedvectors.Vocab at 0x13a50e310>,
#  'prof': <gensim.models.keyedvectors.Vocab at 0x13a50e350>,
#  'dursun': <gensim.models.keyedvectors.Vocab at 0x13a50e390>,
#  'delen': <gensim.models.keyedvectors.Vocab at 0x13a50e3d0>,
#  'scott': <gensim.models.keyedvectors.Vocab at 0x13a50e410>,
#  'fincher': <gensim.models.keyedvectors.Vocab at 0x13a50e450>,
#  'teachers': <gensim.models.keyedvectors.Vocab at 0x13a50e490>,
#  'introduction': <gensim.models.keyedvectors.Vocab at 0x13a50e4d0>,
#  'processing”': <gensim.models.keyedvectors.Vocab at 0x13a50e510>,
#  'course': <gensim.models.keyedvectors.Vocab at 0x13a50e550>,
#  'regularly': <gensim.models.keyedvectors.Vocab at 0x13a50e590>,
#  'run': <gensim.models.keyedvectors.Vocab at 0x13a50e5d0>,
#  'knime': <gensim.models.keyedvectors.Vocab at 0x13a50e610>,
#  'based': <gensim.models.keyedvectors.Vocab at 0x13a50e650>,
#  'processing': <gensim.models.keyedvectors.Vocab at 0x13a50e690>,
#  'extension': <gensim.models.keyedvectors.Vocab at 0x13a50e6d0>,
#  'holder': <gensim.models.keyedvectors.Vocab at 0x13a50e710>,
#  'william': <gensim.models.keyedvectors.Vocab at 0x13a50e750>,
#  'spears': <gensim.models.keyedvectors.Vocab at 0x13a50e790>,
#  'endowed': <gensim.models.keyedvectors.Vocab at 0x13a50e7d0>,
#  'chair': <gensim.models.keyedvectors.Vocab at 0x13a50e810>,
#  'business': <gensim.models.keyedvectors.Vocab at 0x13a50e850>,
#  'administration': <gensim.models.keyedvectors.Vocab at 0x13a50e890>,
#  'patterson': <gensim.models.keyedvectors.Vocab at 0x13a50e8d0>,
#  'family': <gensim.models.keyedvectors.Vocab at 0x13a50e910>,
#  'director': <gensim.models.keyedvectors.Vocab at 0x13a50e950>,
#  'research': <gensim.models.keyedvectors.Vocab at 0x13a50e990>,
#  'center': <gensim.models.keyedvectors.Vocab at 0x13a50e9d0>,
#  'innovation': <gensim.models.keyedvectors.Vocab at 0x13a50ea10>,
#  'regents': <gensim.models.keyedvectors.Vocab at 0x13a50ea50>,
#  'professor': <gensim.models.keyedvectors.Vocab at 0x13a50ea90>,
#  'information': <gensim.models.keyedvectors.Vocab at 0x13a50ead0>,
#  'school': <gensim.models.keyedvectors.Vocab at 0x13a50eb10>,
#  'oklahoma': <gensim.models.keyedvectors.Vocab at 0x13a50eb50>,
#  'state': <gensim.models.keyedvectors.Vocab at 0x13a50eb90>,
#  'osu': <gensim.models.keyedvectors.Vocab at 0x13a50ebd0>,
#  'scientist': <gensim.models.keyedvectors.Vocab at 0x13a50ec10>,
#  'evangelism': <gensim.models.keyedvectors.Vocab at 0x13a50ec50>,
#  'team': <gensim.models.keyedvectors.Vocab at 0x13a50ec90>,
#  'biggest': <gensim.models.keyedvectors.Vocab at 0x13a50ecd0>,
#  'contributors': <gensim.models.keyedvectors.Vocab at 0x13a50ed10>,
#  'forum': <gensim.models.keyedvectors.Vocab at 0x13a50ed50>,
#  'currently': <gensim.models.keyedvectors.Vocab at 0x13a50ed90>,
#  'experiencing': <gensim.models.keyedvectors.Vocab at 0x13a50edd0>,
#  'surge': <gensim.models.keyedvectors.Vocab at 0x13a50ee10>,
#  'popularity': <gensim.models.keyedvectors.Vocab at 0x13a50ee50>,
#  'mainly': <gensim.models.keyedvectors.Vocab at 0x13a50ee90>,
#  'due': <gensim.models.keyedvectors.Vocab at 0x13a50eed0>,
#  'advanced': <gensim.models.keyedvectors.Vocab at 0x13a50ef10>,
#  'chatbots': <gensim.models.keyedvectors.Vocab at 0x13a50ef50>,
#  'advances': <gensim.models.keyedvectors.Vocab at 0x13a50ef90>,
#  'architectures': <gensim.models.keyedvectors.Vocab at 0x13a50efd0>,
#  'free': <gensim.models.keyedvectors.Vocab at 0x13a592050>,
#  'generation': <gensim.models.keyedvectors.Vocab at 0x13a592090>,
#  'generated': <gensim.models.keyedvectors.Vocab at 0x13a5920d0>,
#  'day': <gensim.models.keyedvectors.Vocab at 0x13a592110>,
#  'web': <gensim.models.keyedvectors.Vocab at 0x13a592150>,
#  'commerce': <gensim.models.keyedvectors.Vocab at 0x13a592190>,
#  'social': <gensim.models.keyedvectors.Vocab at 0x13a5921d0>,
#  'media': <gensim.models.keyedvectors.Vocab at 0x13a592210>,
#  'deeper': <gensim.models.keyedvectors.Vocab at 0x13a592250>,
#  'problems': <gensim.models.keyedvectors.Vocab at 0x13a592290>,
#  'analyzing': <gensim.models.keyedvectors.Vocab at 0x13a5922d0>,
#  'documents': <gensim.models.keyedvectors.Vocab at 0x13a592310>,
#  'talking': <gensim.models.keyedvectors.Vocab at 0x13a592350>,
#  'blending': <gensim.models.keyedvectors.Vocab at 0x13a592390>,
#  'sources': <gensim.models.keyedvectors.Vocab at 0x13a5923d0>,
#  'language': <gensim.models.keyedvectors.Vocab at 0x13a592410>,
#  'specific': <gensim.models.keyedvectors.Vocab at 0x13a592450>,
#  'minimum': <gensim.models.keyedvectors.Vocab at 0x13a592490>,
#  'amounts': <gensim.models.keyedvectors.Vocab at 0x13a5924d0>,
#  'commonly': <gensim.models.keyedvectors.Vocab at 0x13a592510>,
#  'posed': <gensim.models.keyedvectors.Vocab at 0x13a592550>,
#  'questions': <gensim.models.keyedvectors.Vocab at 0x13a592590>,
#  'collecting': <gensim.models.keyedvectors.Vocab at 0x13a5925d0>,
#  'rosaria': <gensim.models.keyedvectors.Vocab at 0x13a592610>,
#  'beginning': <gensim.models.keyedvectors.Vocab at 0x13a592650>,
#  'projects': <gensim.models.keyedvectors.Vocab at 0x13a592690>,
#  'proceed': <gensim.models.keyedvectors.Vocab at 0x13a5926d0>,
#  'contained': <gensim.models.keyedvectors.Vocab at 0x13a592710>,
#  'location': <gensim.models.keyedvectors.Vocab at 0x13a592750>,
#  'distributed': <gensim.models.keyedvectors.Vocab at 0x13a592790>,
#  'across': <gensim.models.keyedvectors.Vocab at 0x13a5927d0>,
#  'many': <gensim.models.keyedvectors.Vocab at 0x13a592810>,
#  'websites': <gensim.models.keyedvectors.Vocab at 0x13a592850>,
#  'posts': <gensim.models.keyedvectors.Vocab at 0x13a592890>,
#  'repositories': <gensim.models.keyedvectors.Vocab at 0x13a5928d0>,
#  'organized': <gensim.models.keyedvectors.Vocab at 0x13a592910>,
#  'around': <gensim.models.keyedvectors.Vocab at 0x13a592950>,
#  'topics': <gensim.models.keyedvectors.Vocab at 0x13a592990>,
#  'beginners': <gensim.models.keyedvectors.Vocab at 0x13a5929d0>,
#  'probably': <gensim.models.keyedvectors.Vocab at 0x13a592a10>,
#  'kaggle': <gensim.models.keyedvectors.Vocab at 0x13a592a50>,
#  'number': <gensim.models.keyedvectors.Vocab at 0x13a592a90>,
#  'datasets': <gensim.models.keyedvectors.Vocab at 0x13a592ad0>,
#  'second': <gensim.models.keyedvectors.Vocab at 0x13a592b10>,
#  'located': <gensim.models.keyedvectors.Vocab at 0x13a592b50>,
#  'options': <gensim.models.keyedvectors.Vocab at 0x13a592b90>,
#  'bringing': <gensim.models.keyedvectors.Vocab at 0x13a592bd0>,
#  'workflow': <gensim.models.keyedvectors.Vocab at 0x13a592c10>,
#  'flat': <gensim.models.keyedvectors.Vocab at 0x13a592c50>,
#  'files': <gensim.models.keyedvectors.Vocab at 0x13a592c90>,
#  'file': <gensim.models.keyedvectors.Vocab at 0x13a592cd0>,
#  'reader': <gensim.models.keyedvectors.Vocab at 0x13a592d10>,
#  'node': <gensim.models.keyedvectors.Vocab at 0x13a592d50>,
#  'individual': <gensim.models.keyedvectors.Vocab at 0x13a592d90>,
#  'tika': <gensim.models.keyedvectors.Vocab at 0x13a592dd0>,
#  'parser': <gensim.models.keyedvectors.Vocab at 0x13a592e10>,
#  'reading': <gensim.models.keyedvectors.Vocab at 0x13a592e50>,
#  'large': <gensim.models.keyedvectors.Vocab at 0x13a592e90>,
#  'groups': <gensim.models.keyedvectors.Vocab at 0x13a592ed0>,
#  'folders': <gensim.models.keyedvectors.Vocab at 0x13a592f10>,
#  'full': <gensim.models.keyedvectors.Vocab at 0x13a592f50>,
#  'word': <gensim.models.keyedvectors.Vocab at 0x13a592f90>,
#  'pdf': <gensim.models.keyedvectors.Vocab at 0x13a592fd0>,
#  'especially': <gensim.models.keyedvectors.Vocab at 0x13a595050>,
#  'flexible': <gensim.models.keyedvectors.Vocab at 0x13a595090>,
#  'read': <gensim.models.keyedvectors.Vocab at 0x13a5950d0>,
#  'variety': <gensim.models.keyedvectors.Vocab at 0x13a595110>,
#  'formats': <gensim.models.keyedvectors.Vocab at 0x13a595150>,
#  'database': <gensim.models.keyedvectors.Vocab at 0x13a595190>,
#  'platform': <gensim.models.keyedvectors.Vocab at 0x13a5951d0>,
#  'nodes': <gensim.models.keyedvectors.Vocab at 0x13a595210>,
#  'access': <gensim.models.keyedvectors.Vocab at 0x13a595250>,
#  'sites': <gensim.models.keyedvectors.Vocab at 0x13a595290>,
#  'webpage': <gensim.models.keyedvectors.Vocab at 0x13a5952d0>,
#  'retriever': <gensim.models.keyedvectors.Vocab at 0x13a595310>,
#  'rest': <gensim.models.keyedvectors.Vocab at 0x13a595350>,
#  'api': <gensim.models.keyedvectors.Vocab at 0x13a595390>,
#  'request': <gensim.models.keyedvectors.Vocab at 0x13a5953d0>,
#  'accessing': <gensim.models.keyedvectors.Vocab at 0x13a595410>,
#  'tweets': <gensim.models.keyedvectors.Vocab at 0x13a595450>,
#  'directly': <gensim.models.keyedvectors.Vocab at 0x13a595490>,
#  'strengths': <gensim.models.keyedvectors.Vocab at 0x13a5954d0>,
#  'pull': <gensim.models.keyedvectors.Vocab at 0x13a595510>,
#  'blend': <gensim.models.keyedvectors.Vocab at 0x13a595550>,
#  'wide': <gensim.models.keyedvectors.Vocab at 0x13a595590>,
#  'examples': <gensim.models.keyedvectors.Vocab at 0x13a5955d0>,
#  'grabbing': <gensim.models.keyedvectors.Vocab at 0x13a595610>,
#  'docx': <gensim.models.keyedvectors.Vocab at 0x13a595650>,
#  'scraping': <gensim.models.keyedvectors.Vocab at 0x13a595690>,
#  'workflows': <gensim.models.keyedvectors.Vocab at 0x13a5956d0>,
#  'available': <gensim.models.keyedvectors.Vocab at 0x13a595710>,
#  'started': <gensim.models.keyedvectors.Vocab at 0x13a595750>,
#  'demonstrates': <gensim.models.keyedvectors.Vocab at 0x13a595790>,
#  'local': <gensim.models.keyedvectors.Vocab at 0x13a5957d0>,
#  'remote': <gensim.models.keyedvectors.Vocab at 0x13a595810>,
#  'pages': <gensim.models.keyedvectors.Vocab at 0x13a595850>,
#  'combine': <gensim.models.keyedvectors.Vocab at 0x13a595890>,
#  'together': <gensim.models.keyedvectors.Vocab at 0x13a5958d0>,
#  'it’s': <gensim.models.keyedvectors.Vocab at 0x13a595910>,
#  'hub': <gensim.models.keyedvectors.Vocab at 0x13a595950>,
#  '“will': <gensim.models.keyedvectors.Vocab at 0x13a595990>,
#  'meets': <gensim.models.keyedvectors.Vocab at 0x13a5959d0>,
#  'crawling”': <gensim.models.keyedvectors.Vocab at 0x13a595a10>,
#  'kni': <gensim.models.keyedvectors.Vocab at 0x13a595a50>,
#  'igo2cb4vhphvmiqf': <gensim.models.keyedvectors.Vocab at 0x13a595a90>,
#  'along': <gensim.models.keyedvectors.Vocab at 0x13a595ad0>,
#  'lots': <gensim.models.keyedvectors.Vocab at 0x13a595b10>,
#  'place': <gensim.models.keyedvectors.Vocab at 0x13a595b50>,
#  'components': <gensim.models.keyedvectors.Vocab at 0x13a595b90>,
#  'extensions': <gensim.models.keyedvectors.Vocab at 0x13a595bd0>,
#  'built': <gensim.models.keyedvectors.Vocab at 0x13a595c10>,
#  'wider': <gensim.models.keyedvectors.Vocab at 0x13a595c50>,
#  'community': <gensim.models.keyedvectors.Vocab at 0x13a595c90>,
#  'keywords': <gensim.models.keyedvectors.Vocab at 0x13a595cd0>,
#  'algorithms': <gensim.models.keyedvectors.Vocab at 0x13a595d10>,
#  'whatever': <gensim.models.keyedvectors.Vocab at 0x13a595d50>,
#  'interest': <gensim.models.keyedvectors.Vocab at 0x13a595d90>,
#  'maybe': <gensim.models.keyedvectors.Vocab at 0x13a595dd0>,
#  'really': <gensim.models.keyedvectors.Vocab at 0x13a595e10>,
#  'benefit': <gensim.models.keyedvectors.Vocab at 0x13a595e50>,
#  'everyone': <gensim.models.keyedvectors.Vocab at 0x13a595e90>,
#  'upload': <gensim.models.keyedvectors.Vocab at 0x13a595ed0>,
#  'share': <gensim.models.keyedvectors.Vocab at 0x13a595f10>,
#  'connecting': <gensim.models.keyedvectors.Vocab at 0x13a595f50>,
#  'easily': <gensim.models.keyedvectors.Vocab at 0x13a595f90>,
#  'prefer': <gensim.models.keyedvectors.Vocab at 0x13a595fd0>,
#  'amazon': <gensim.models.keyedvectors.Vocab at 0x13a597050>,
#  'azure': <gensim.models.keyedvectors.Vocab at 0x13a597090>,
#  'recently': <gensim.models.keyedvectors.Vocab at 0x13a5970d0>,
#  'updated': <gensim.models.keyedvectors.Vocab at 0x13a597110>,
#  'booklet': <gensim.models.keyedvectors.Vocab at 0x13a597150>,
#  'press': <gensim.models.keyedvectors.Vocab at 0x13a597190>,
#  'site': <gensim.models.keyedvectors.Vocab at 0x13a5971d0>,
#  'freely': <gensim.models.keyedvectors.Vocab at 0x13a597210>,
#  'focuses': <gensim.models.keyedvectors.Vocab at 0x13a597250>,
#  'ways': <gensim.models.keyedvectors.Vocab at 0x13a597290>,
#  'kinds': <gensim.models.keyedvectors.Vocab at 0x13a5972d0>,
#  'download': <gensim.models.keyedvectors.Vocab at 0x13a597310>,
#  'explore': <gensim.models.keyedvectors.Vocab at 0x13a597350>,
#  'dictionaries': <gensim.models.keyedvectors.Vocab at 0x13a597390>,
#  'move': <gensim.models.keyedvectors.Vocab at 0x13a5973d0>,
#  'next': <gensim.models.keyedvectors.Vocab at 0x13a597410>,
#  '“tokenization”': <gensim.models.keyedvectors.Vocab at 0x13a597450>,
#  'refer': <gensim.models.keyedvectors.Vocab at 0x13a597490>,
#  'tokenization': <gensim.models.keyedvectors.Vocab at 0x13a5974d0>,
#  'separating': <gensim.models.keyedvectors.Vocab at 0x13a597510>,
#  'textual': <gensim.models.keyedvectors.Vocab at 0x13a597550>,
#  'document': <gensim.models.keyedvectors.Vocab at 0x13a597590>,
#  'low': <gensim.models.keyedvectors.Vocab at 0x13a5975d0>,
#  'units': <gensim.models.keyedvectors.Vocab at 0x13a597610>,
#  'numbers': <gensim.models.keyedvectors.Vocab at 0x13a597650>,
#  'characters': <gensim.models.keyedvectors.Vocab at 0x13a597690>,
#  'tokenizer': <gensim.models.keyedvectors.Vocab at 0x13a5976d0>,
#  'basic': <gensim.models.keyedvectors.Vocab at 0x13a597710>,
#  'strings': <gensim.models.keyedvectors.Vocab at 0x13a597750>,
#  'opennlp': <gensim.models.keyedvectors.Vocab at 0x13a597790>,
#  'english': <gensim.models.keyedvectors.Vocab at 0x13a5977d0>,
#  'whitespace': <gensim.models.keyedvectors.Vocab at 0x13a597810>,
#  'stanford': <gensim.models.keyedvectors.Vocab at 0x13a597850>,
#  'nlp': <gensim.models.keyedvectors.Vocab at 0x13a597890>,
#  'tokenizers': <gensim.models.keyedvectors.Vocab at 0x13a5978d0>,
#  'agnostic': <gensim.models.keyedvectors.Vocab at 0x13a597910>,
#  'white': <gensim.models.keyedvectors.Vocab at 0x13a597950>,
#  'sophisticated': <gensim.models.keyedvectors.Vocab at 0x13a597990>,
#  'found': <gensim.models.keyedvectors.Vocab at 0x13a5979d0>,
#  'languages': <gensim.models.keyedvectors.Vocab at 0x13a597a10>,
#  'recommendation': <gensim.models.keyedvectors.Vocab at 0x13a597a50>,
#  'nothing': <gensim.models.keyedvectors.Vocab at 0x13a597a90>,
#  'else': <gensim.models.keyedvectors.Vocab at 0x13a597ad0>,
#  'remove': <gensim.models.keyedvectors.Vocab at 0x13a597b10>,
#  'punctuation': <gensim.models.keyedvectors.Vocab at 0x13a597b50>,
#  'yes': <gensim.models.keyedvectors.Vocab at 0x13a597b90>,
#  'erasure': <gensim.models.keyedvectors.Vocab at 0x13a597bd0>,
#  'easiest': <gensim.models.keyedvectors.Vocab at 0x13a597c10>,
#  'textprocessing': <gensim.models.keyedvectors.Vocab at 0x13a597c50>,
#  'there’s': <gensim.models.keyedvectors.Vocab at 0x13a597c90>,
#  'almost': <gensim.models.keyedvectors.Vocab at 0x13a597cd0>,
#  'configuration': <gensim.models.keyedvectors.Vocab at 0x13a597d10>,
#  'apply': <gensim.models.keyedvectors.Vocab at 0x13a597d50>,
#  'continue': <gensim.models.keyedvectors.Vocab at 0x13a597d90>,
#  'sometimes': <gensim.models.keyedvectors.Vocab at 0x13a597dd0>,
#  'still': <gensim.models.keyedvectors.Vocab at 0x13a597e10>,
#  'hyphens': <gensim.models.keyedvectors.Vocab at 0x13a597e50>,
#  'tokenized': <gensim.models.keyedvectors.Vocab at 0x13a597e90>,
#  'removal': <gensim.models.keyedvectors.Vocab at 0x13a597ed0>,
#  'that’s': <gensim.models.keyedvectors.Vocab at 0x13a597f10>,
#  'revisit': <gensim.models.keyedvectors.Vocab at 0x13a597f50>,
#  'create': <gensim.models.keyedvectors.Vocab at 0x13a597f90>,
#  'dictionary': <gensim.models.keyedvectors.Vocab at 0x13a597fd0>,
#  'stop': <gensim.models.keyedvectors.Vocab at 0x13a59c050>,
#  'filter': <gensim.models.keyedvectors.Vocab at 0x13a59c090>,
#  'internal': <gensim.models.keyedvectors.Vocab at 0x13a59c0d0>,
#  'provide': <gensim.models.keyedvectors.Vocab at 0x13a59c110>,
#  'table': <gensim.models.keyedvectors.Vocab at 0x13a59c150>,
#  'consisting': <gensim.models.keyedvectors.Vocab at 0x13a59c190>,
#  'column': <gensim.models.keyedvectors.Vocab at 0x13a59c1d0>,
#  'row': <gensim.models.keyedvectors.Vocab at 0x13a59c210>,
#  'feed': <gensim.models.keyedvectors.Vocab at 0x13a59c250>,
#  'optional': <gensim.models.keyedvectors.Vocab at 0x13a59c290>,
#  'input': <gensim.models.keyedvectors.Vocab at 0x13a59c2d0>,
#  'port': <gensim.models.keyedvectors.Vocab at 0x13a59c310>,
#  'approach': <gensim.models.keyedvectors.Vocab at 0x13a59c350>,
#  'custom': <gensim.models.keyedvectors.Vocab at 0x13a59c390>,
#  'tagger': <gensim.models.keyedvectors.Vocab at 0x13a59c3d0>,
#  'classic': <gensim.models.keyedvectors.Vocab at 0x13a59c410>,
#  'requiring': <gensim.models.keyedvectors.Vocab at 0x13a59c450>,
#  'popular': <gensim.models.keyedvectors.Vocab at 0x13a59c490>,
#  'nowadays': <gensim.models.keyedvectors.Vocab at 0x13a59c4d0>,
#  'sentiment': <gensim.models.keyedvectors.Vocab at 0x13a59c510>,
#  'analysis': <gensim.models.keyedvectors.Vocab at 0x13a59c550>,
#  'detection': <gensim.models.keyedvectors.Vocab at 0x13a59c590>,
#  'extract': <gensim.models.keyedvectors.Vocab at 0x13a59c5d0>,
#  'knowledge': <gensim.models.keyedvectors.Vocab at 0x13a59c610>,
#  'reviews': <gensim.models.keyedvectors.Vocab at 0x13a59c650>,
#  'products': <gensim.models.keyedvectors.Vocab at 0x13a59c690>,
#  'services': <gensim.models.keyedvectors.Vocab at 0x13a59c6d0>,
#  'classification': <gensim.models.keyedvectors.Vocab at 0x13a59c710>,
#  'similar': <gensim.models.keyedvectors.Vocab at 0x13a59c750>,
#  'supervised': <gensim.models.keyedvectors.Vocab at 0x13a59c790>,
#  'version': <gensim.models.keyedvectors.Vocab at 0x13a59c7d0>,
#  'classes': <gensim.models.keyedvectors.Vocab at 0x13a59c810>,
#  'limited': <gensim.models.keyedvectors.Vocab at 0x13a59c850>,
#  'degrees': <gensim.models.keyedvectors.Vocab at 0x13a59c890>,
#  'negative': <gensim.models.keyedvectors.Vocab at 0x13a59c8d0>,
#  'feeling': <gensim.models.keyedvectors.Vocab at 0x13a59c910>,
#  'area': <gensim.models.keyedvectors.Vocab at 0x13a59c950>,
#  'showing': <gensim.models.keyedvectors.Vocab at 0x13a59c990>,
#  'academic': <gensim.models.keyedvectors.Vocab at 0x13a59c9d0>,
#  'circles': <gensim.models.keyedvectors.Vocab at 0x13a59ca10>,
#  'literature': <gensim.models.keyedvectors.Vocab at 0x13a59ca50>,
#  'discover': <gensim.models.keyedvectors.Vocab at 0x13a59ca90>,
#  'latent': <gensim.models.keyedvectors.Vocab at 0x13a59cad0>,
#  'papers': <gensim.models.keyedvectors.Vocab at 0x13a59cb10>,
#  'dominance': <gensim.models.keyedvectors.Vocab at 0x13a59cb50>,
#  'overtime': <gensim.models.keyedvectors.Vocab at 0x13a59cb90>,
#  'relationship': <gensim.models.keyedvectors.Vocab at 0x13a59cbd0>,
#  'journals': <gensim.models.keyedvectors.Vocab at 0x13a59cc10>,
#  'disciplines': <gensim.models.keyedvectors.Vocab at 0x13a59cc50>,
#  'point': <gensim.models.keyedvectors.Vocab at 0x13a59cc90>,
#  'conceptually': <gensim.models.keyedvectors.Vocab at 0x13a59ccd0>,
#  'easy': <gensim.models.keyedvectors.Vocab at 0x13a59cd10>,
#  'grasp': <gensim.models.keyedvectors.Vocab at 0x13a59cd50>,
#  'treated': <gensim.models.keyedvectors.Vocab at 0x13a59cd90>,
#  'complexity': <gensim.models.keyedvectors.Vocab at 0x13a59cdd0>,
#  'running': <gensim.models.keyedvectors.Vocab at 0x13a59ce10>,
#  'lexicon': <gensim.models.keyedvectors.Vocab at 0x13a59ce50>,
#  'implementing': <gensim.models.keyedvectors.Vocab at 0x13a59ce90>,
#  'linked': <gensim.models.keyedvectors.Vocab at 0x13a59ced0>,
#  'imdb': <gensim.models.keyedvectors.Vocab at 0x13a59cf10>,
#  'movie': <gensim.models.keyedvectors.Vocab at 0x13a59cf50>,
#  'try': <gensim.models.keyedvectors.Vocab at 0x13a59cf90>,
#  'classify': <gensim.models.keyedvectors.Vocab at 0x13a59cfd0>,
#  'another': <gensim.models.keyedvectors.Vocab at 0x13a59f050>,
#  'approached': <gensim.models.keyedvectors.Vocab at 0x13a59f090>,
#  'beginner': <gensim.models.keyedvectors.Vocab at 0x13a59f0d0>,
#  'extraction': <gensim.models.keyedvectors.Vocab at 0x13a59f110>,
#  'lda': <gensim.models.keyedvectors.Vocab at 0x13a59f150>,
#  'titled': <gensim.models.keyedvectors.Vocab at 0x13a59f190>,
#  '“topic': <gensim.models.keyedvectors.Vocab at 0x13a59f1d0>,
#  'extraction”': <gensim.models.keyedvectors.Vocab at 0x13a59f210>,
#  'parallel': <gensim.models.keyedvectors.Vocab at 0x13a59f250>,
#  'tripadvisor': <gensim.models.keyedvectors.Vocab at 0x13a59f290>,
#  'restaurant': <gensim.models.keyedvectors.Vocab at 0x13a59f2d0>,
#  'you’re': <gensim.models.keyedvectors.Vocab at 0x13a59f310>,
#  'importing': <gensim.models.keyedvectors.Vocab at 0x13a59f350>,
#  'exploratory': <gensim.models.keyedvectors.Vocab at 0x13a59f390>,
#  'visualization': <gensim.models.keyedvectors.Vocab at 0x13a59f3d0>,
#  '“interactive': <gensim.models.keyedvectors.Vocab at 0x13a59f410>,
#  'tag': <gensim.models.keyedvectors.Vocab at 0x13a59f450>,
#  'search”': <gensim.models.keyedvectors.Vocab at 0x13a59f490>,
#  'show': <gensim.models.keyedvectors.Vocab at 0x13a59f4d0>,
#  'unsupervised': <gensim.models.keyedvectors.Vocab at 0x13a59f510>,
#  'stands': <gensim.models.keyedvectors.Vocab at 0x13a59f550>,
#  'dirichlet': <gensim.models.keyedvectors.Vocab at 0x13a59f590>,
#  'allocation': <gensim.models.keyedvectors.Vocab at 0x13a59f5d0>,
#  'produces': <gensim.models.keyedvectors.Vocab at 0x13a59f610>,
#  'pre': <gensim.models.keyedvectors.Vocab at 0x13a59f650>,
#  'determined': <gensim.models.keyedvectors.Vocab at 0x13a59f690>,
#  'hidden': <gensim.models.keyedvectors.Vocab at 0x13a59f6d0>,
#  'output': <gensim.models.keyedvectors.Vocab at 0x13a59f710>,
#  'fold': <gensim.models.keyedvectors.Vocab at 0x13a59f750>,
#  'defines': <gensim.models.keyedvectors.Vocab at 0x13a59f790>,
#  'extractor': <gensim.models.keyedvectors.Vocab at 0x13a59f7d0>,
#  'outputs': <gensim.models.keyedvectors.Vocab at 0x13a59f810>,
#  'tables': <gensim.models.keyedvectors.Vocab at 0x13a59f850>,
#  'here’s': <gensim.models.keyedvectors.Vocab at 0x13a59f890>,
#  '“large': <gensim.models.keyedvectors.Vocab at 0x13a59f8d0>,
#  'large”': <gensim.models.keyedvectors.Vocab at 0x13a59f910>,
#  'computational': <gensim.models.keyedvectors.Vocab at 0x13a59f950>,
#  'power': <gensim.models.keyedvectors.Vocab at 0x13a59f990>,
#  'issue': <gensim.models.keyedvectors.Vocab at 0x13a59f9d0>,
#  'coming': <gensim.models.keyedvectors.Vocab at 0x13a59fa10>,
#  'representative': <gensim.models.keyedvectors.Vocab at 0x13a59fa50>,
#  'domain': <gensim.models.keyedvectors.Vocab at 0x13a59fa90>,
#  'larger': <gensim.models.keyedvectors.Vocab at 0x13a59fad0>,
#  'rule': <gensim.models.keyedvectors.Vocab at 0x13a59fb10>,
#  'thumb': <gensim.models.keyedvectors.Vocab at 0x13a59fb50>,
#  'quantities': <gensim.models.keyedvectors.Vocab at 0x13a59fb90>,
#  'smaller': <gensim.models.keyedvectors.Vocab at 0x13a59fbd0>,
#  'size': <gensim.models.keyedvectors.Vocab at 0x13a59fc10>,
#  'tend': <gensim.models.keyedvectors.Vocab at 0x13a59fc50>,
#  'reliable': <gensim.models.keyedvectors.Vocab at 0x13a59fc90>,
#  'alternatives': <gensim.models.keyedvectors.Vocab at 0x13a59fcd0>,
#  'latest': <gensim.models.keyedvectors.Vocab at 0x13a59fd10>,
#  'greatest': <gensim.models.keyedvectors.Vocab at 0x13a59fd50>,
#  'methods': <gensim.models.keyedvectors.Vocab at 0x13a59fd90>,
#  'newer': <gensim.models.keyedvectors.Vocab at 0x13a59fdd0>,
#  'word2vec': <gensim.models.keyedvectors.Vocab at 0x13a59fe10>,
#  'wordembedding': <gensim.models.keyedvectors.Vocab at 0x13a59fe50>,
#  'rnns': <gensim.models.keyedvectors.Vocab at 0x13a59fe90>,
#  'lstms': <gensim.models.keyedvectors.Vocab at 0x13a59fed0>,
#  'dimension': <gensim.models.keyedvectors.Vocab at 0x13a59ff10>,
#  'including': <gensim.models.keyedvectors.Vocab at 0x13a59ff50>,
#  'contextual': <gensim.models.keyedvectors.Vocab at 0x13a59ff90>,
#  'positional': <gensim.models.keyedvectors.Vocab at 0x13a59ffd0>,
#  'sequential': <gensim.models.keyedvectors.Vocab at 0x13a5a3050>,
#  'nature': <gensim.models.keyedvectors.Vocab at 0x13a5a3090>,
#  'years': <gensim.models.keyedvectors.Vocab at 0x13a5a30d0>,
#  'ago': <gensim.models.keyedvectors.Vocab at 0x13a5a3110>,
#  'clustering': <gensim.models.keyedvectors.Vocab at 0x13a5a3150>,
#  'raw': <gensim.models.keyedvectors.Vocab at 0x13a5a3190>,
#  'matrices': <gensim.models.keyedvectors.Vocab at 0x13a5a31d0>,
#  'tdm': <gensim.models.keyedvectors.Vocab at 0x13a5a3210>,
#  'repeated': <gensim.models.keyedvectors.Vocab at 0x13a5a3250>,
#  'svd': <gensim.models.keyedvectors.Vocab at 0x13a5a3290>,
#  'singular': <gensim.models.keyedvectors.Vocab at 0x13a5a32d0>,
#  'decomposition': <gensim.models.keyedvectors.Vocab at 0x13a5a3310>,
#  'values': <gensim.models.keyedvectors.Vocab at 0x13a5a3350>,
#  'produced': <gensim.models.keyedvectors.Vocab at 0x13a5a3390>,
#  'pretty': <gensim.models.keyedvectors.Vocab at 0x13a5a33d0>,
#  'study': <gensim.models.keyedvectors.Vocab at 0x13a5a3410>,
#  'high': <gensim.models.keyedvectors.Vocab at 0x13a5a3450>,
#  'impact': <gensim.models.keyedvectors.Vocab at 0x13a5a3490>,
#  'journal': <gensim.models.keyedvectors.Vocab at 0x13a5a34d0>,
#  'contract': <gensim.models.keyedvectors.Vocab at 0x13a5a3510>,
#  'conditions': <gensim.models.keyedvectors.Vocab at 0x13a5a3550>,
#  'anything': <gensim.models.keyedvectors.Vocab at 0x13a5a3590>,
#  'contracting': <gensim.models.keyedvectors.Vocab at 0x13a5a35d0>,
#  'heard': <gensim.models.keyedvectors.Vocab at 0x13a5a3610>,
#  'patent': <gensim.models.keyedvectors.Vocab at 0x13a5a3650>,
#  'law': <gensim.models.keyedvectors.Vocab at 0x13a5a3690>,
#  'records': <gensim.models.keyedvectors.Vocab at 0x13a5a36d0>,
#  'genomics': <gensim.models.keyedvectors.Vocab at 0x13a5a3710>,
#  'biomedicine': <gensim.models.keyedvectors.Vocab at 0x13a5a3750>,
#  'covid': <gensim.models.keyedvectors.Vocab at 0x13a5a3790>,
#  'months': <gensim.models.keyedvectors.Vocab at 0x13a5a37d0>,
#  '200k': <gensim.models.keyedvectors.Vocab at 0x13a5a3810>,
#  'appeared': <gensim.models.keyedvectors.Vocab at 0x13a5a3850>,
#  'cannot': <gensim.models.keyedvectors.Vocab at 0x13a5a3890>,
#  'manually': <gensim.models.keyedvectors.Vocab at 0x13a5a38d0>,
#  'colleagues': <gensim.models.keyedvectors.Vocab at 0x13a5a3910>,
#  'corpus': <gensim.models.keyedvectors.Vocab at 0x13a5a3950>,
#  'discovery': <gensim.models.keyedvectors.Vocab at 0x13a5a3990>,
#  'meta': <gensim.models.keyedvectors.Vocab at 0x13a5a39d0>,
#  'advice': <gensim.models.keyedvectors.Vocab at 0x13a5a3a10>,
#  'spam': <gensim.models.keyedvectors.Vocab at 0x13a5a3a50>,
#  'filtering': <gensim.models.keyedvectors.Vocab at 0x13a5a3a90>,
#  ...}

# %%
word_count_dict
# Out:
# {'start': 108,
#  'incorporating': 8,
#  'machine': 592,
#  'learning': 811,
#  'models': 238,
#  'user': 117,
#  'applications': 216,
#  'question': 50,
#  'comes': 121,
#  '“when': 2,
#  'model': 410,
#  'good': 150,
#  'enough': 56,
#  'deploy': 20,
#  'simply': 44,
#  'single': 60,
#  'right': 165,
#  'answer': 35,
#  'clear': 45,
#  'cut': 20,
#  'measure': 33,
#  'ready': 33,
#  'put': 49,
#  'production': 44,
#  'set': 150,
#  'thought': 24,
#  'experiments': 5,
#  'new': 818,
#  'identify': 106,
#  'goal': 36,
#  'trying': 46,
#  'decide': 20,
#  'deployment': 43,
#  'helpful': 26,
#  'circle': 2,
#  'back': 175,
#  'algorithm’s': 2,
#  'original': 19,
#  'predict': 63,
#  'customer': 265,
#  'churn': 6,
#  'reach': 61,
#  'client': 42,
#  'intent': 5,
#  'automatically': 39,
#  'approve': 3,
#  'deny': 3,
#  'someone’s': 1,
#  'credit': 50,
#  'application': 89,
#  'use': 705,
#  'case': 120,
#  'determine': 66,
#  'stringent': 6,
#  'requirements': 38,
#  'instance': 48,
#  'suggesting': 4,
#  'things': 86,
#  'wildly': 2,
#  'different': 262,
#  'compared': 20,
#  'algorithm': 88,
#  'designed': 36,
#  'make': 385,
#  'decisions': 99,
#  'autonomous': 16,
#  'driving': 47,
#  'space': 43,
#  'example': 161,
#  'illustrated': 10,
#  'dilemma': 1,
#  'six': 18,
#  'levels': 36,
#  'autonomy': 3,
#  'might': 194,
#  'imagine': 16,
#  'subsequent': 10,
#  'level': 95,
#  'would': 234,
#  'stricter': 3,
#  'vehicle': 14,
#  'explained': 13,
#  'depending': 22,
#  'type': 55,
#  'may': 219,
#  'able': 135,
#  'away': 28,
#  'potentially': 20,
#  'need': 420,
#  'roll': 5,
#  'stages': 20,
#  'require': 36,
#  'thresholds': 3,
#  'appropriate': 15,
#  'basis': 29,
#  'strive': 9,
#  'metric': 7,
#  'combination': 21,
#  'metrics': 44,
#  'decides': 2,
#  'whether': 83,
#  'depends': 10,
#  'accuracy': 61,
#  'vital': 33,
#  'often': 106,
#  'talked': 36,
#  'without': 129,
#  'accurate': 41,
#  'predictions': 45,
#  'purpose': 25,
#  'deploying': 10,
#  'best': 244,
#  'within': 119,
#  'reasonable': 5,
#  'limitations': 15,
#  'however': 226,
#  'direct': 29,
#  'test': 89,
#  'even': 274,
#  'important': 246,
#  'let': 47,
#  'someone': 24,
#  'needs': 127,
#  'surgery': 7,
#  'problem': 95,
#  'operate': 20,
#  'sick': 2,
#  'people': 217,
#  'could': 217,
#  'consider': 76,
#  'operating': 26,
#  'healthy': 8,
#  'patient': 66,
#  'much': 179,
#  'significant': 67,
#  'mistake': 12,
#  'cases': 132,
#  'like': 344,
#  'false': 47,
#  'positives': 9,
#  'dangerous': 8,
#  'precision': 9,
#  'recall': 4,
#  'score': 35,
#  'keep': 127,
#  'simple': 76,
#  'article': 257,
#  'let’s': 59,
#  'focus': 57,
#  'practical': 17,
#  'terms': 77,
#  'you’ll': 50,
#  'confirming': 2,
#  'two': 162,
#  'phases': 9,
#  'training': 140,
#  'phase': 21,
#  'separate': 15,
#  'testing': 50,
#  'evaluate': 37,
#  'generally': 37,
#  'aside': 7,
#  'portion': 7,
#  'data': 3574,
#  'validation': 43,
#  'validate': 9,
#  'trained': 43,
#  'used': 312,
#  'several': 68,
#  'times': 55,
#  'find': 206,
#  'optimal': 25,
#  'hyperparameters': 7,
#  'michael': 2,
#  'mccourt': 1,
#  'sigopt': 1,
#  'wrote': 11,
#  'split': 29,
#  'mlops': 17,
#  'get': 283,
#  'model’s': 4,
#  'using': 393,
#  'hasn’t': 5,
#  'iterations': 8,
#  'generalize': 4,
#  'words': 51,
#  'produce': 32,
#  'memorized': 1,
#  'answers': 31,
#  'term': 57,
#  'overfitting': 6,
#  'performs': 7,
#  'well': 242,
#  'fails': 4,
#  'cassie': 1,
#  'kozyrkov': 1,
#  'google': 139,
#  'done': 44,
#  'fantastic': 4,
#  'short': 38,
#  'explainer': 2,
#  'validating': 7,
#  'codify': 3,
#  'engineering': 44,
#  'perspective': 19,
#  'criteria': 10,
#  'making': 147,
#  'sure': 86,
#  'codified': 1,
#  'pipeline': 19,
#  'written': 30,
#  'baselines': 1,
#  'adhered': 1,
#  'newly': 7,
#  'deployed': 16,
#  'serve': 25,
#  'benchmark': 2,
#  'future': 183,
#  'always': 92,
#  'compare': 16,
#  'similarly': 16,
#  'perform': 51,
#  'part': 123,
#  'rather': 40,
#  'manual': 21,
#  'process': 280,
#  'script': 3,
#  'setting': 15,
#  'train': 161,
#  'build': 95,
#  'system': 194,
#  'continuously': 15,
#  'retrain': 1,
#  'maintain': 29,
#  'product': 128,
#  'interested': 32,
#  'pipelines': 7,
#  'related': 63,
#  'content': 120,
#  'originally': 8,
#  'published': 49,
#  'https': 160,
#  'valohai': 4,
#  'varying': 4,
#  'patients': 75,
#  'growing': 82,
#  'better': 247,
#  'management': 197,
#  'healthcare': 222,
#  'driven': 137,
#  'companies': 345,
#  'look': 108,
#  'help': 391,
#  'technology': 442,
#  'suffice': 3,
#  'say': 49,
#  'answered': 1,
#  'call': 51,
#  'plenty': 18,
#  'resources': 83,
#  'offer': 96,
#  'quality': 89,
#  'none': 21,
#  'proven': 14,
#  'quite': 34,
#  'potent': 3,
#  'internet': 124,
#  'essentially': 20,
#  'network': 102,
#  'devices': 86,
#  'connected': 29,
#  'via': 55,
#  'context': 15,
#  'empowers': 5,
#  'providers': 54,
#  'ability': 73,
#  'utilize': 45,
#  'gathered': 5,
#  'sensors': 11,
#  'etc': 63,
#  'achieve': 33,
#  'impactful': 2,
#  'results': 122,
#  'every': 169,
#  'step': 109,
#  'starting': 27,
#  'early': 29,
#  'diagnosis': 17,
#  'remotely': 8,
#  'monitoring': 75,
#  'patients’': 8,
#  'statistics': 56,
#  'iot': 76,
#  'encouraged': 1,
#  'enabled': 16,
#  'world': 178,
#  'positive': 31,
#  'change': 93,
#  'sector': 59,
#  'listed': 29,
#  'understand': 144,
#  'benefits': 182,
#  'medicine': 18,
#  'dose': 4,
#  'doctor': 11,
#  'tell': 26,
#  'regular': 19,
#  'intake': 3,
#  'underpins': 2,
#  'treatment': 10,
#  'plan': 64,
#  'effectiveness': 12,
#  'way': 241,
#  'ensure': 64,
#  'don’t': 99,
#  'fall': 19,
#  'behind': 35,
#  'proper': 17,
#  'prescribed': 1,
#  'tools': 313,
#  'enable': 41,
#  'professionals': 40,
#  'regulate': 5,
#  'amount': 56,
#  'eye': 25,
#  'efficacy': 2,
#  'miss': 5,
#  'reminder': 1,
#  'sent': 15,
#  'project': 93,
#  'adjusted': 4,
#  'automation': 111,
#  'mentioned': 36,
#  'elaborate': 3,
#  'complicated': 16,
#  'brimming': 1,
#  'mundane': 7,
#  'tasks': 95,
#  'facilities': 14,
#  'automate': 35,
#  'daily': 26,
#  'administrative': 6,
#  'necessarily': 8,
#  'human': 133,
#  'intervention': 11,
#  'plus': 11,
#  'analyze': 48,
#  'passes': 3,
#  'systems': 151,
#  'monitor': 34,
#  'changes': 89,
#  'health': 118,
#  'reduced': 12,
#  'costs': 92,
#  'critical': 82,
#  'unfortunate': 3,
#  'truth': 24,
#  'expensive': 30,
#  'parties': 19,
#  'equation': 3,
#  'regard': 12,
#  'allowing': 29,
#  'consult': 3,
#  'doctors': 15,
#  'needing': 5,
#  'travel': 13,
#  'facility': 8,
#  'helps': 111,
#  'streamline': 26,
#  'databases': 39,
#  'long': 110,
#  'cutting': 14,
#  'hospitals': 32,
#  'great': 99,
#  'must': 114,
#  'dive': 8,
#  'headfirst': 1,
#  'first': 176,
#  'taking': 47,
#  'time': 509,
#  'acquaint': 1,
#  'challenges': 53,
#  'security': 192,
#  'abundance': 5,
#  'sensitive': 15,
#  'involved': 36,
#  'translating': 4,
#  'risks': 51,
#  'integration': 50,
#  'since': 101,
#  'entire': 42,
#  'concept': 27,
#  'underpinned': 1,
#  'idea': 47,
#  'denying': 2,
#  'suppose': 8,
#  'genuinely': 2,
#  'leverage': 49,
#  'potential': 94,
#  'recommend': 21,
#  'carefully': 14,
#  'strategizing': 1,
#  'development': 161,
#  'software': 327,
#  'solution': 77,
#  'overcome': 9,
#  'associated': 39,
#  'ones': 41,
#  'welcome': 11,
#  'dsc': 33,
#  'weekly': 17,
#  'digest': 6,
#  'science': 413,
#  'central': 40,
#  'week': 57,
#  'pick': 18,
#  'newest': 5,
#  'brightest': 1,
#  'articles': 118,
#  'topic': 30,
#  'informs': 3,
#  'lives': 27,
#  'powers': 1,
#  'provides': 59,
#  'insights': 141,
#  'editor': 19,
#  'desk': 16,
#  'creation': 29,
#  'assets': 37,
#  'remember': 16,
#  'happens': 14,
#  'stored': 38,
#  'certain': 60,
#  'theory': 17,
#  'created': 65,
#  'fairly': 10,
#  'deep': 140,
#  'understanding': 95,
#  'modeling': 40,
#  'design': 95,
#  'practice': 26,
#  'programmers': 10,
#  'optimized': 12,
#  'particular': 56,
#  'actually': 51,
#  'lot': 159,
#  'got': 23,
#  'ancient': 1,
#  'legacy': 12,
#  'takes': 44,
#  'brings': 22,
#  'value': 192,
#  'cardinality': 1,
#  'properly': 31,
#  'captured': 6,
#  'managed': 13,
#  'dimensions': 9,
#  'maintained': 3,
#  'consistent': 19,
#  'reality': 24,
#  'work': 238,
#  'getting': 86,
#  'compute': 19,
#  'cycles': 4,
#  'seem': 24,
#  'easier': 96,
#  'machines': 26,
#  'handle': 36,
#  'comprehensible': 1,
#  'matters': 14,
#  'selection': 59,
#  'informative': 6,
#  'provoking': 1,
#  'writing': 12,
#  'check': 55,
#  'guidelines': 12,
#  'know': 147,
#  'think': 59,
#  'featured': 17,
#  'collection': 33,
#  'text': 80,
#  'interpretation': 9,
#  'manager': 15,
#  'key': 89,
#  'success': 76,
#  'predicting': 21,
#  'heart': 12,
#  'disease': 23,
#  'independent': 19,
#  'variables': 80,
#  'include': 92,
#  'regressi': 1,
#  'ssl': 25,
#  'certificates': 35,
#  'phishers': 4,
#  'what’s': 50,
#  'professions': 3,
#  'scientists': 95,
#  'leveraging': 30,
#  'everything': 64,
#  'generative': 7,
#  'adversarial': 11,
#  'networks': 100,
#  'depth': 16,
#  'devops': 22,
#  'developers': 47,
#  'interesting': 31,
#  'poisson': 14,
#  'binomial': 16,
#  'distribution': 32,
#  'covariance': 14,
#  'correlation': 21,
#  'digital': 267,
#  'robber': 16,
#  'barons': 9,
#  'vertical': 19,
#  'university': 47,
#  'rwanda': 7,
#  'institution': 12,
#  'africa': 6,
#  'join': 14,
#  'significance': 10,
#  'probability': 57,
#  'mass': 12,
#  'function': 82,
#  'density': 12,
#  'three': 77,
#  'steps': 62,
#  'conquering': 2,
#  'last': 65,
#  'mile': 5,
#  'analytics': 606,
#  'public': 76,
#  'cloud': 212,
#  'indispensable': 4,
#  'component': 27,
#  'businesses': 184,
#  'tech': 61,
#  'target': 80,
#  'brain': 14,
#  'teasers': 2,
#  'fun': 8,
#  'tips': 15,
#  'python': 59,
#  'presidential': 9,
#  'polling': 5,
#  'misses': 3,
#  'mark': 25,
#  '2020': 61,
#  'infosys': 2,
#  'launches': 6,
#  'applied': 43,
#  'enterprises': 32,
#  'rights': 7,
#  'pay': 35,
#  'taxes': 3,
#  'days': 45,
#  'twins': 15,
#  'supply': 65,
#  'chain': 68,
#  'picture': 49,
#  'source': 225,
#  'emails': 44,
#  'please': 19,
#  'add': 97,
#  'email': 126,
#  'protected': 20,
#  'address': 79,
#  'book': 66,
#  'whitelist': 6,
#  'subscribe': 18,
#  'newsletter': 9,
#  'comprehensive': 22,
#  'repository': 11,
#  'videos': 28,
#  'search': 116,
#  'post': 56,
#  'blog': 54,
#  'ask': 44,
#  'follow': 46,
#  'twitter': 125,
#  'datasciencectrl': 2,
#  'analyticbridge': 2,
#  'meet': 22,
#  'mining': 167,
#  'experts': 55,
#  'today’s': 23,
#  'interview': 33,
#  'explores': 3,
#  'common': 73,
#  'issues': 69,
#  'faced': 17,
#  'prof': 2,
#  'dursun': 18,
#  'delen': 2,
#  'scott': 18,
#  'fincher': 2,
#  'teachers': 11,
#  'introduction': 25,
#  'processing”': 1,
#  'course': 81,
#  'regularly': 13,
#  'run': 65,
#  'knime': 35,
#  'based': 283,
#  'processing': 118,
#  'extension': 15,
#  'holder': 1,
#  'william': 4,
#  'spears': 2,
#  'endowed': 2,
#  'chair': 3,
#  'business': 565,
#  'administration': 4,
#  'patterson': 1,
#  'family': 16,
#  'director': 14,
#  'research': 137,
#  'center': 21,
#  'innovation': 39,
#  'regents': 1,
#  'professor': 7,
#  'information': 376,
#  'school': 16,
#  'oklahoma': 1,
#  'state': 86,
#  'osu': 1,
#  'scientist': 65,
#  'evangelism': 1,
#  'team': 123,
#  'biggest': 63,
#  'contributors': 2,
#  'forum': 6,
#  'currently': 38,
#  'experiencing': 4,
#  'surge': 5,
#  'popularity': 17,
#  'mainly': 11,
#  'due': 64,
#  'advanced': 65,
#  'chatbots': 36,
#  'advances': 32,
#  'architectures': 13,
#  'free': 113,
#  'generation': 47,
#  'generated': 27,
#  'day': 66,
#  'web': 107,
#  'commerce': 12,
#  'social': 125,
#  'media': 103,
#  'deeper': 15,
#  'problems': 86,
#  'analyzing': 26,
#  'documents': 29,
#  'talking': 20,
#  'blending': 1,
#  'sources': 88,
#  'language': 102,
#  'specific': 108,
#  'minimum': 11,
#  'amounts': 28,
#  'commonly': 9,
#  'posed': 3,
#  'questions': 79,
#  'collecting': 23,
#  'rosaria': 29,
#  'beginning': 13,
#  'projects': 55,
#  'proceed': 6,
#  'contained': 5,
#  'location': 38,
#  'distributed': 26,
#  'across': 96,
#  'many': 361,
#  'websites': 46,
#  'posts': 21,
#  'repositories': 7,
#  'organized': 11,
#  'around': 92,
#  'topics': 23,
#  'beginners': 5,
#  'probably': 22,
#  'kaggle': 7,
#  'number': 191,
#  'datasets': 35,
#  'second': 33,
#  'located': 7,
#  'options': 54,
#  'bringing': 8,
#  'workflow': 21,
#  'flat': 1,
#  'files': 30,
#  'file': 38,
#  'reader': 6,
#  'node': 24,
#  'individual': 45,
#  'tika': 2,
#  'parser': 2,
#  'reading': 30,
#  'large': 129,
#  'groups': 33,
#  'folders': 3,
#  'full': 126,
#  'word': 21,
#  'pdf': 15,
#  'especially': 97,
#  'flexible': 9,
#  'read': 51,
#  'variety': 40,
#  'formats': 8,
#  'database': 60,
#  'platform': 143,
#  'nodes': 14,
#  'access': 134,
#  'sites': 33,
#  'webpage': 2,
#  'retriever': 1,
#  'rest': 18,
#  'api': 23,
#  'request': 11,
#  'accessing': 12,
#  'tweets': 2,
#  'directly': 38,
#  'strengths': 5,
#  'pull': 7,
#  'blend': 3,
#  'wide': 34,
#  'examples': 50,
#  'grabbing': 2,
#  'docx': 1,
#  'scraping': 29,
#  'workflows': 14,
#  'available': 123,
#  'started': 51,
#  'demonstrates': 11,
#  'local': 33,
#  'remote': 39,
#  'pages': 40,
#  'combine': 22,
#  'together': 54,
#  'it’s': 225,
#  'hub': 12,
#  '“will': 2,
#  'meets': 8,
#  'crawling”': 1,
#  'kni': 1,
#  'igo2cb4vhphvmiqf': 1,
#  'along': 34,
#  'lots': 15,
#  'place': 85,
#  'components': 46,
#  'extensions': 2,
#  'built': 44,
#  'wider': 11,
#  'community': 34,
#  'keywords': 34,
#  'algorithms': 153,
#  'whatever': 16,
#  'interest': 30,
#  'maybe': 8,
#  'really': 46,
#  'benefit': 51,
#  'everyone': 36,
#  'upload': 5,
#  'share': 537,
#  'connecting': 6,
#  'easily': 79,
#  'prefer': 17,
#  'amazon': 28,
#  'azure': 4,
#  'recently': 37,
#  'updated': 17,
#  'booklet': 1,
#  'press': 8,
#  'site': 62,
#  'freely': 6,
#  'focuses': 13,
#  'ways': 154,
#  'kinds': 14,
#  'download': 23,
#  'explore': 28,
#  'dictionaries': 3,
#  'move': 62,
#  'next': 99,
#  '“tokenization”': 1,
#  'refer': 12,
#  'tokenization': 4,
#  'separating': 5,
#  'textual': 6,
#  'document': 20,
#  'low': 30,
#  'units': 14,
#  'numbers': 45,
#  'characters': 8,
#  'tokenizer': 6,
#  'basic': 44,
#  'strings': 5,
#  'opennlp': 2,
#  'english': 11,
#  'whitespace': 1,
#  'stanford': 3,
#  'nlp': 22,
#  'tokenizers': 1,
#  'agnostic': 4,
#  'white': 7,
#  'sophisticated': 20,
#  'found': 58,
#  'languages': 41,
#  'recommendation': 17,
#  'nothing': 22,
#  'else': 20,
#  'remove': 13,
#  'punctuation': 3,
#  'yes': 12,
#  'erasure': 1,
#  'easiest': 4,
#  'textprocessing': 3,
#  'there’s': 34,
#  'almost': 53,
#  'configuration': 21,
#  'apply': 46,
#  'continue': 32,
#  'sometimes': 31,
#  'still': 116,
#  'hyphens': 1,
#  'tokenized': 1,
#  'removal': 3,
#  'that’s': 77,
#  'revisit': 2,
#  'create': 192,
#  'dictionary': 5,
#  'stop': 27,
#  'filter': 4,
#  'internal': 44,
#  'provide': 154,
#  'table': 41,
#  'consisting': 2,
#  'column': 9,
#  'row': 33,
#  'feed': 10,
#  'optional': 4,
#  'input': 123,
#  'port': 3,
#  'approach': 78,
#  'custom': 28,
#  'tagger': 1,
#  'classic': 11,
#  'requiring': 7,
#  'popular': 55,
#  'nowadays': 7,
#  'sentiment': 18,
#  'analysis': 177,
#  'detection': 40,
#  'extract': 32,
#  'knowledge': 117,
#  'reviews': 19,
#  'products': 103,
#  'services': 262,
#  'classification': 33,
#  'similar': 88,
#  'supervised': 42,
#  'version': 23,
#  'classes': 12,
#  'limited': 25,
#  'degrees': 13,
#  'negative': 21,
#  'feeling': 4,
#  'area': 45,
#  'showing': 11,
#  'academic': 13,
#  'circles': 2,
#  'literature': 7,
#  'discover': 23,
#  'latent': 4,
#  'papers': 12,
#  'dominance': 2,
#  'overtime': 2,
#  'relationship': 27,
#  'journals': 4,
#  'disciplines': 6,
#  'point': 86,
#  'conceptually': 1,
#  'easy': 89,
#  'grasp': 7,
#  'treated': 2,
#  'complexity': 12,
#  'running': 39,
#  'lexicon': 3,
#  'implementing': 28,
#  'linked': 14,
#  'imdb': 2,
#  'movie': 31,
#  'try': 54,
#  'classify': 8,
#  'another': 107,
#  'approached': 2,
#  'beginner': 7,
#  'extraction': 60,
#  'lda': 14,
#  'titled': 5,
#  '“topic': 1,
#  'extraction”': 2,
#  'parallel': 13,
#  'tripadvisor': 1,
#  'restaurant': 3,
#  'you’re': 67,
#  'importing': 2,
#  'exploratory': 4,
#  'visualization': 30,
#  '“interactive': 1,
#  'tag': 10,
#  'search”': 1,
#  'show': 44,
#  'unsupervised': 47,
#  'stands': 8,
#  'dirichlet': 1,
#  'allocation': 8,
#  'produces': 12,
#  'pre': 23,
#  'determined': 10,
#  'hidden': 22,
#  'output': 35,
#  'fold': 14,
#  'defines': 13,
#  'extractor': 1,
#  'outputs': 21,
#  'tables': 14,
#  'here’s': 13,
#  '“large': 1,
#  'large”': 1,
#  'computational': 21,
#  'power': 83,
#  'issue': 24,
#  'coming': 32,
#  'representative': 8,
#  'domain': 34,
#  'larger': 20,
#  'rule': 19,
#  'thumb': 3,
#  'quantities': 6,
#  'smaller': 29,
#  'size': 51,
#  'tend': 23,
#  'reliable': 26,
#  'alternatives': 5,
#  'latest': 40,
#  'greatest': 10,
#  'methods': 74,
#  'newer': 9,
#  'word2vec': 1,
#  'wordembedding': 1,
#  'rnns': 2,
#  'lstms': 2,
#  'dimension': 9,
#  'including': 83,
#  'contextual': 13,
#  'positional': 1,
#  'sequential': 8,
#  'nature': 34,
#  'years': 118,
#  'ago': 20,
#  'clustering': 25,
#  'raw': 17,
#  'matrices': 2,
#  'tdm': 1,
#  'repeated': 2,
#  'svd': 7,
#  'singular': 7,
#  'decomposition': 6,
#  'values': 49,
#  'produced': 13,
#  'pretty': 14,
#  'study': 52,
#  'high': 117,
#  'impact': 68,
#  'journal': 4,
#  'contract': 13,
#  'conditions': 28,
#  'anything': 20,
#  'contracting': 3,
#  'heard': 13,
#  'patent': 4,
#  'law': 22,
#  'records': 34,
#  'genomics': 4,
#  'biomedicine': 1,
#  'covid': 58,
#  'months': 33,
#  '200k': 1,
#  'appeared': 9,
#  'cannot': 34,
#  'manually': 17,
#  'colleagues': 4,
#  'corpus': 4,
#  'discovery': 23,
#  'meta': 8,
#  'advice': 31,
#  'spam': 11,
#  'filtering': 8,
#  ...}

# %%
sorted_word_count_dict = {k: v for k, v in sorted(word_count_dict.items(), key=lambda item: item[1])}

# %%
sorted_word_count_dict
# Out:
# {'someone’s': 1,
#  'dilemma': 1,
#  'mccourt': 1,
#  'sigopt': 1,
#  'memorized': 1,
#  'cassie': 1,
#  'kozyrkov': 1,
#  'codified': 1,
#  'baselines': 1,
#  'adhered': 1,
#  'retrain': 1,
#  'answered': 1,
#  'encouraged': 1,
#  'prescribed': 1,
#  'reminder': 1,
#  'brimming': 1,
#  'headfirst': 1,
#  'acquaint': 1,
#  'underpinned': 1,
#  'strategizing': 1,
#  'brightest': 1,
#  'powers': 1,
#  'ancient': 1,
#  'cardinality': 1,
#  'comprehensible': 1,
#  'provoking': 1,
#  'regressi': 1,
#  'processing”': 1,
#  'holder': 1,
#  'patterson': 1,
#  'regents': 1,
#  'oklahoma': 1,
#  'osu': 1,
#  'evangelism': 1,
#  'blending': 1,
#  'flat': 1,
#  'retriever': 1,
#  'docx': 1,
#  'crawling”': 1,
#  'kni': 1,
#  'igo2cb4vhphvmiqf': 1,
#  'booklet': 1,
#  '“tokenization”': 1,
#  'whitespace': 1,
#  'tokenizers': 1,
#  'erasure': 1,
#  'hyphens': 1,
#  'tokenized': 1,
#  'tagger': 1,
#  'conceptually': 1,
#  '“topic': 1,
#  'tripadvisor': 1,
#  '“interactive': 1,
#  'search”': 1,
#  'dirichlet': 1,
#  'extractor': 1,
#  '“large': 1,
#  'large”': 1,
#  'word2vec': 1,
#  'wordembedding': 1,
#  'positional': 1,
#  'tdm': 1,
#  'biomedicine': 1,
#  '200k': 1,
#  'deception': 1,
#  'truthful': 1,
#  'preprocess': 1,
#  'evergreen': 1,
#  'justify': 1,
#  'marginal': 1,
#  'spanish': 1,
#  'punctuations': 1,
#  'survivability': 1,
#  'cerner': 1,
#  '70m': 1,
#  'nurse': 1,
#  'sanitize': 1,
#  'governmental': 1,
#  'nurses’': 1,
#  '“bounceback”': 1,
#  'settled': 1,
#  'sewn': 1,
#  'standalone': 1,
#  'triggering': 1,
#  'falter': 1,
#  '200m': 1,
#  'challenger': 1,
#  'performer': 1,
#  'beaten': 1,
#  'sufficiently': 1,
#  'idiosyncrasies': 1,
#  '“nothing': 1,
#  'specifics': 1,
#  'wraps': 1,
#  'meantime': 1,
#  'wishing': 1,
#  'exam': 1,
#  'exams': 1,
#  'originate': 1,
#  '“text': 1,
#  'discussion”': 1,
#  'sep': 1,
#  'conductor': 1,
#  'orchestra': 1,
#  'demanding': 1,
#  'soldier': 1,
#  'cornerstones': 1,
#  'visionary': 1,
#  'swat': 1,
#  'budgeting': 1,
#  'persuades': 1,
#  'rigidity': 1,
#  'realistically': 1,
#  'timeframes': 1,
#  'trickiest': 1,
#  'empathy': 1,
#  'diplomacy': 1,
#  'mentoring': 1,
#  'micromanagement': 1,
#  'kills': 1,
#  'stamina': 1,
#  'multitasking': 1,
#  'nerve': 1,
#  'racking': 1,
#  'pmi': 1,
#  'scrummaster': 1,
#  'csm': 1,
#  'coursera': 1,
#  'mastery': 1,
#  'udemy': 1,
#  'msc': 1,
#  'viv': 1,
#  'ukraine': 1,
#  'competent': 1,
#  'prudence': 1,
#  'outstaffing': 1,
#  'softwa': 1,
#  'unsplash': 1,
#  '‘heart': 1,
#  'prediction’': 1,
#  'improvised': 1,
#  'proclaimed': 1,
#  'naïve': 1,
#  '“predicting': 1,
#  'unpack': 1,
#  'scrutinize': 1,
#  'paramedic': 1,
#  'diastolic': 1,
#  'cholesterol': 1,
#  'arenot': 1,
#  'deduce': 1,
#  '“favorable': 1,
#  'aggravating': 1,
#  '‘best’': 1,
#  'fixate': 1,
#  '‘goodhart’s': 1,
#  '‘when': 1,
#  'ceases': 1,
#  'sketchplanations': 1,
#  'implying': 1,
#  '‘causation’': 1,
#  'believing': 1,
#  'trap': 1,
#  'counterproductive': 1,
#  'dosage': 1,
#  'medicines': 1,
#  'biostatistics': 1,
#  'tumors': 1,
#  'excised': 1,
#  'professors': 1,
#  'idiosyncratic': 1,
#  '“stepwise': 1,
#  'selection”': 1,
#  'hosmer': 1,
#  'collinearity': 1,
#  'sheepish': 1,
#  'grin': 1,
#  '“secret”': 1,
#  'inferior': 1,
#  'commences': 1,
#  '“fish”': 1,
#  'qualify': 1,
#  'epidemiology': 1,
#  'rounds': 1,
#  'qualifies': 1,
#  'round’s': 1,
#  '“break”': 1,
#  'tussling': 1,
#  'collinear': 1,
#  'dicey': 1,
#  'inflation': 1,
#  'starker': 1,
#  'pants': 1,
#  'pervasive': 1,
#  'fabricated': 1,
#  'systemic': 1,
#  '‘https’': 1,
#  '‘http’': 1,
#  'sockets': 1,
#  'initiating': 1,
#  'handshake': 1,
#  'verifies': 1,
#  'others’': 1,
#  'mock': 1,
#  'cue': 1,
#  'phishlabs': 1,
#  'renew': 1,
#  'outages': 1,
#  'openphish': 1,
#  'phishtank': 1,
#  'cali': 1,
#  'prohibited': 1,
#  'signature': 1,
#  'blurred': 1,
#  'expiration': 1,
#  'indications': 1,
#  'eternal': 1,
#  '483': 1,
#  '275': 1,
#  'synthesise': 1,
#  'generalisability': 1,
#  'favourite…': 1,
#  'favourite': 1,
#  'fewest': 1,
#  'stratified': 1,
#  'maximising': 1,
#  'minimising': 1,
#  '528': 1,
#  '967': 1,
#  'uplift': 1,
#  'qas': 1,
#  'retrained': 1,
#  'lock': 1,
#  'pryce': 1,
#  '‘the': 1,
#  'work’': 1,
#  'individuals—employees': 1,
#  'professionals—get': 1,
#  'upended': 1,
#  'subsumed': 1,
#  'relocate': 1,
#  'consultancies': 1,
#  'interests—how': 1,
#  'oncoming': 1,
#  'reasoned': 1,
#  'attend': 1,
#  'marketable': 1,
#  'preponderance': 1,
#  'contemplating': 1,
#  'gretzky': 1,
#  '‘skates': 1,
#  'puck': 1,
#  'additions': 1,
#  'enablers': 1,
#  'workers—employees': 1,
#  'contractors—are': 1,
#  'formulation': 1,
#  'desirability': 1,
#  'crucially': 1,
#  'competes': 1,
#  'imply': 1,
#  'forthright': 1,
#  'hallmark': 1,
#  'wisdom': 1,
#  'graduates': 1,
#  'compensated': 1,
#  'ensued': 1,
#  'cutthroat': 1,
#  'dump': 1,
#  'cheaply': 1,
#  'supervising': 1,
#  'displaced': 1,
#  'diminished': 1,
#  'innumerable': 1,
#  'accommodating': 1,
#  'it—from': 1,
#  'fluid': 1,
#  'charting': 1,
#  'holistically': 1,
#  'recompense': 1,
#  'weakness': 1,
#  'marriage': 1,
#  'retard': 1,
#  'bears': 1,
#  'predominance': 1,
#  'frees': 1,
#  'blunt': 1,
#  'discard': 1,
#  'actuating': 1,
#  'temptation': 1,
#  'automation’s': 1,
#  '“waterfall”': 1,
#  'democratization': 1,
#  'predominately': 1,
#  'lag': 1,
#  'unsecured': 1,
#  'uncontrolled': 1,
#  'noncompliant': 1,
#  'dormant': 1,
#  'guesstimate': 1,
#  'droves': 1,
#  'possession': 1,
#  'projections': 1,
#  'continent': 1,
#  'prestigious': 1,
#  'rwanda’s': 1,
#  'curricula': 1,
#  '“africa': 1,
#  'eastern': 1,
#  'regional': 1,
#  'subsidy': 1,
#  'ingerly': 1,
#  'disintermediate': 1,
#  '“moneyball”': 1,
#  '“moneyball': 1,
#  'reinvented': 1,
#  '“winning': 1,
#  '“vertical': 1,
#  'indissoluble': 1,
#  'operated': 1,
#  'whereby': 1,
#  'moats”': 1,
#  'moat”': 1,
#  'popularized': 1,
#  'warren': 1,
#  'buffett': 1,
#  'onerous': 1,
#  'medieval': 1,
#  'riches': 1,
#  'moats': 1,
#  'blast': 1,
#  'furnaces': 1,
#  'railroads': 1,
#  'witnessing': 1,
#  'mastering': 1,
#  '“visualized': 1,
#  'capitalist': 1,
#  'visualcapitalist': 1,
#  'foods': 1,
#  'heck': 1,
#  'redshift': 1,
#  'sagemaker': 1,
#  'ridiculously': 1,
#  'brilliant…unless': 1,
#  'harvest': 1,
#  'scale”': 1,
#  'infinitely': 1,
#  'barons…meet': 1,
#  'ruthless': 1,
#  'businessmen': 1,
#  '19th': 1,
#  'wiki': 1,
#  'industrialist': 1,
#  'economicmoat': 1,
#  'asp': 1,
#  '“carnegie': 1,
#  'america”': 1,
#  'hbs': 1,
#  'rctom': 1,
#  'coigher': 1,
#  'haverage': 1,
#  'versa': 1,
#  'incase': 1,
#  'jargon': 1,
#  'favoring': 1,
#  'mathematicians': 1,
#  'combinatorial': 1,
#  '485': 1,
#  'millionth': 1,
#  'virtue': 1,
#  '577215…': 1,
#  'euler–mascheroni': 1,
#  '033913': 1,
#  'equality': 1,
#  'mertens': 1,
#  'asymptotic': 1,
#  'equivalence': 1,
#  'denote': 1,
#  '11920': 1,
#  'approx': 1,
#  '1068': 1,
#  'bigint': 1,
#  'perl': 1,
#  'primeq': 1,
#  'mathematica': 1,
#  'sagemath': 1,
#  'calculator': 1,
#  'oeis': 1,
#  'constants': 1,
#  'primality': 1,
#  'integer': 1,
#  '145': 1,
#  'magnitude': 1,
#  'mathematician': 1,
#  'wiley': 1,
#  'doc': 1,
#  'cnet': 1,
#  'nbc': 1,
#  'ebay': 1,
#  'exit': 1,
#  '“commit': 1,
#  'defective': 1,
#  'repairing': 1,
#  'defects': 1,
#  'resembling': 1,
#  'defect': 1,
#  'fiddly': 1,
#  'futile': 1,
#  'transmitting': 1,
#  'emphasizes': 1,
#  'prolonged': 1,
#  'mixed': 1,
#  'murphy': 1,
#  'friction': 1,
#  'tossed': 1,
#  'modifications': 1,
#  'settlement': 1,
#  'ian': 1,
#  'goodfellow': 1,
#  'mnist': 1,
#  'phase1': 1,
#  'zeros': 1,
#  'discriminator’s': 1,
#  'gradients': 1,
#  'collab': 1,
#  'collapses': 1,
#  '“collapses”': 1,
#  'fools': 1,
#  'preferable': 1,
#  'experimented': 1,
#  '“mini': 1,
#  'discrimination”': 1,
#  'punishing': 1,
#  'punish': 1,
#  'instability': 1,
#  'discriminate': 1,
#  'oscillation': 1,
#  'scholar': 1,
#  'xdigest': 1,
#  'elect': 1,
#  'perceptions': 1,
#  'contemplate': 1,
#  'pmf': 1,
#  '“last': 1,
#  'mile”': 1,
#  'continuum': 1,
#  'shelfware': 1,
#  'cdos': 1,
#  'caos': 1,
#  'conquer': 1,
#  'masses': 1,
#  'deliverable': 1,
#  'elevating': 1,
#  'accepts': 1,
#  'alignment': 1,
#  'intervened': 1,
#  'approvals': 1,
#  'inevitably': 1,
#  'overheads': 1,
#  'availing': 1,
#  'smoother': 1,
#  'favourable': 1,
#  'coordination': 1,
#  'glory': 1,
#  'personalised': 1,
#  'predominant': 1,
#  'organisational': 1,
#  'interpersonal': 1,
#  'skilful': 1,
#  'cultivates': 1,
#  'paradigms': 1,
#  'skype': 1,
#  'itsm': 1,
#  'crms': 1,
#  'expertly': 1,
#  'interprets': 1,
#  'superseding': 1,
#  'ebooks': 1,
#  '732': 1,
#  '283': 1,
#  '0499': 1,
#  'sebastian': 1,
#  'raschka': 1,
#  'literal': 1,
#  'plotted': 1,
#  'ressources': 1,
#  'wizardry': 1,
#  'adjusts': 1,
#  'regressor': 1,
#  'disk': 1,
#  'cran': 1,
#  'rconsole': 1,
#  '“devtools”': 1,
#  '‘ajayarunachalam': 1,
#  'metaensembler’': 1,
#  'ref': 1,
#  '‘main’': 1,
#  '111': 1,
#  '←read': 1,
#  '←house': 1,
#  '414': 1,
#  'attach': 1,
#  '“iris”': 1,
#  '“bar”': 1,
#  '‘bar’': 1,
#  '“rock”': 1,
#  '‘lm’': 1,
#  '‘rf’': 1,
#  'rscript': 1,
#  'goovy': 1,
#  'xrange': 1,
#  'cpython': 1,
#  'interpreters': 1,
#  'void': 1,
#  'args': 1,
#  'confirms': 1,
#  'profiling': 1,
#  'jvms': 1,
#  'sergei': 1,
#  'chekanov': 1,
#  'belle': 1,
#  'alan': 1,
#  'ioannis': 1,
#  'papantonis': 1,
#  'quantifying': 1,
#  'intrinsic': 1,
#  'agnistic': 1,
#  'approximates': 1,
#  'explaining': 1,
#  'feature’s': 1,
#  'coalitional': 1,
#  'ice': 1,
#  'cs50’s': 1,
#  'harvardx': 1,
#  '“degrees': 1,
#  'separation”': 1,
#  'starred': 1,
#  '“apollo': 1,
#  '870': 1,
#  '696w': 1,
#  '696px': 1,
#  'imdb’s': 1,
#  'establishes': 1,
#  'edges': 1,
#  '640px': 1,
#  'alternates': 1,
#  'unmodified': 1,
#  'horizontally': 1,
#  'diagonally': 1,
#  'invalid': 1,
#  'allowable': 1,
#  'speedup': 1,
#  'computer’s': 1,
#  'denotes': 1,
#  'gray': 1,
#  '1978': 1,
#  'logician': 1,
#  'raymond': 1,
#  '“knights': 1,
#  'knaves”': 1,
#  'conversely': 1,
#  'itertoolsclass': 1,
#  'classmethod': 1,
#  'cls': 1,
#  'typeerror': 1,
#  'unary': 1,
#  'inherit': 1,
#  'repr': 1,
#  'parenthesize': 1,
#  'bknight': 1,
#  'bknave': 1,
#  'cknight': 1,
#  'cknave': 1,
#  'knowledge1': 1,
#  'outputting': 1,
#  '373': 1,
#  'ol5uleak2f9stovz': 1,
#  '298w': 1,
#  '298px': 1,
#  '“mines': 1,
#  'detonates': 1,
#  '“safe”': 1,
#  'diagonal': 1,
#  'vw98e5liwtvokhfj': 1,
#  'finger': 1,
#  'm7lh0dvaouji10h9': 1,
#  'expresses': 1,
#  'intractable': 1,
#  '2⁶⁴': 1,
#  'lends': 1,
#  '356': 1,
#  'boebd': 1,
#  'tksr8jdnj': 1,
#  '285w': 1,
#  '285px': 1,
#  'fnpa9phrec': 1,
#  'spten': 1,
#  '292w': 1,
#  '292px': 1,
#  'incidentally': 1,
#  '354': 1,
#  '7scdgg3niwxxwzhd': 1,
#  '283w': 1,
#  '283px': 1,
#  '851': 1,
#  '681w': 1,
#  '681px': 1,
#  'undetermined': 1,
#  'minesweeperai': 1,
#  'decrement': 1,
#  'subplot': 1,
#  'incompetent': 1,
#  'convince': 1,
#  'questioned': 1,
#  'adverse': 1,
#  'aspirations': 1,
#  'undermined': 1,
#  'synced': 1,
#  'baidu’s': 1,
#  'lincoln': 1,
#  'mkz': 1,
#  'apolloscape’s': 1,
#  'kitti': 1,
#  'cityscapes': 1,
#  'bicycles': 1,
#  'pedestrians': 1,
#  'streetlights': 1,
#  'nonstop': 1,
#  'oblige': 1,
#  'vanish': 1,
#  'igmguru': 1,
#  'igmguru’s': 1,
#  'ola': 1,
#  'flipkart': 1,
#  'preference': 1,
#  'owing': 1,
#  'focussing': 1,
#  'scie': 1,
#  'dearth': 1,
#  'carved': 1,
#  'admittedly': 1,
#  '25x': 1,
#  'nd4j': 1,
#  'deeplearning4j': 1,
#  'effortless': 1,
#  'redistribution': 1,
#  'crunchberries': 1,
#  'synergizing': 1,
#  'composable': 1,
#  '“business”': 1,
#  'learningand': 1,
#  'intimate': 1,
#  'upfront': 1,
#  'realization': 1,
#  '“journey”': 1,
#  'intimately': 1,
#  '“process': 1,
#  'context—based': 1,
#  'nielsen': 1,
#  'norman': 1,
#  '“diagram': 1,
#  'touchpoints': 1,
#  '“fundamental': 1,
#  '“consume”': 1,
#  'freed': 1,
#  '“transit': 1,
#  'marin': 1,
#  '“operational': 1,
#  'excellence”': 1,
#  'unplanned': 1,
#  'consumables': 1,
#  'salvage': 1,
#  'tightly': 1,
#  'synergize': 1,
#  '“product': 1,
#  '“engineering”': 1,
#  'designers’': 1,
#  'sla': 1,
#  'decomposes': 1,
#  'marrying': 1,
#  'mastered': 1,
#  'nngroup': 1,
#  'junkie': 1,
#  'preoccupied': 1,
#  'percolating': 1,
#  'ecnn': 1,
#  'strange': 1,
#  'quixotic': 1,
#  'races': 1,
#  'governing': 1,
#  'unleashed': 1,
#  'lea': 1,
#  'cazena': 1,
#  'broadband’s': 1,
#  'iot’s': 1,
#  'theologies': 1,
#  'manifestation': 1,
#  'forgotten': 1,
#  'inventing': 1,
#  'unused': 1,
#  'intention': 1,
#  'incomprehension': 1,
#  'inclination': 1,
#  'welcoming': 1,
#  'collectively': 1,
#  'subsist': 1,
#  'motivate': 1,
#  'summarise': 1,
#  'insinuations': 1,
#  'researchers’': 1,
#  'confusing': 1,
#  'ushers': 1,
#  'habit': 1,
#  'bitter': 1,
#  '7829033033': 1,
#  'standstill': 1,
#  'preparatory': 1,
#  'disequilibrium': 1,
#  'speedening': 1,
#  'cream': 1,
#  'citrix': 1,
#  'doubling': 1,
#  'widening': 1,
#  'laggards': 1,
#  'godspeed': 1,
#  'lowering': 1,
#  'fourth': 1,
#  'pivoting': 1,
#  '“agility”': 1,
#  'procurement': 1,
#  'unclarity': 1,
#  'refocus': 1,
#  'ceos': 1,
#  'cmos': 1,
#  'ode': 1,
#  'inflow': 1,
#  'leg': 1,
#  'expedite': 1,
#  'perfection': 1,
#  'good’s': 1,
#  'enemy': 1,
#  'pulls': 1,
#  '“after': 1,
#  'assembled': 1,
#  'plan”': 1,
#  'manifesto': 1,
#  'software”': 1,
#  'parting': 1,
#  'newness': 1,
#  'usa’s': 1,
#  'plethora': 1,
#  'capitalise': 1,
#  'amid': 1,
#  'extraordinarily': 1,
#  'contend': 1,
#  'prioritising': 1,
#  'scrambling': 1,
#  'resourcing': 1,
#  'lacked': 1,
#  'promptly': 1,
#  'exabytes': 1,
#  'that‘s': 1,
#  '212': 1,
#  'incomprehensible': 1,
#  'bankers': 1,
#  'inconsistencies': 1,
#  'sinister': 1,
#  'accidental': 1,
#  'premeditated': 1,
#  'categorised': 1,
#  '“structured”': 1,
#  '“unstructured”': 1,
#  'posing': 1,
#  'prioritise': 1,
#  'clients’': 1,
#  'behavioural': 1,
#  'consumer’s': 1,
#  '“lifetime': 1,
#  'value”': 1,
#  'recreation': 1,
#  'motion': 1,
#  'lounge': 1,
#  'baffling': 1,
#  'liable': 1,
#  'interacted': 1,
#  'programmes': 1,
#  'customised': 1,
#  'grouplens': 1,
#  'pioneered': 1,
#  'factorization': 1,
#  'typing': 1,
#  'playlist': 1,
#  'rounakbanik': 1,
#  'pandas': 1,
#  'numpy': 1,
#  'budeget': 1,
#  '100000': 1,
#  'quantile': 1,
#  'loc': 1,
#  'barh': 1,
#  'gca': 1,
#  'invert': 1,
#  'yaxis': 1,
#  'avatar': 1,
#  'scipy': 1,
#  'colab': 1,
#  'toy': 1,
#  'action1': 1,
#  'romantic2': 1,
#  '‘rmse’': 1,
#  '9313': 1,
#  'serendipitous': 1,
#  'rohit': 1,
#  'sharma': 1,
#  'upgrad': 1,
#  'iiit': 1,
#  'bangalore': 1,
#  'diploma': 1,
#  'threatens': 1,
#  'shutter': 1,
#  'studios': 1,
#  'quiet': 1,
#  'desperate': 1,
#  'haired': 1,
#  'appearing': 1,
#  'magazines': 1,
#  'indistinguishable': 1,
#  'matte': 1,
#  'overlays': 1,
#  'reels': 1,
#  'spokespeople': 1,
#  'flesh': 1,
#  'bustling': 1,
#  'staring': 1,
#  'dirigibles': 1,
#  'flying': 1,
#  'saucers': 1,
#  'uninhabited': 1,
#  'caribbean': 1,
#  'reserving': 1,
#  'filming': 1,
#  'observers': 1,
#  'donnas': 1,
#  'seldom': 1,
#  'tropical': 1,
#  'island': 1,
#  'malleable': 1,
#  'overdrive': 1,
#  'walt': 1,
#  'disney': 1,
#  'cgi': 1,
#  'mandalorian': 1,
#  'awaited': 1,
#  'governor': 1,
#  'newcom': 1,
#  'loosening': 1,
#  'hyperrealistic': 1,
#  'texture': 1,
#  'shading': 1,
#  'subdermal': 1,
#  'dint': 1,
#  'gameplay': 1,
#  'rigging': 1,
#  'shaders': 1,
#  'dirt': 1,
#  'smoke': 1,
#  'decent': 1,
#  'composites': 1,
#  'verisimilitude': 1,
#  'portraits': 1,
#  'simulating': 1,
#  'tinder': 1,
#  'trolling': 1,
#  'dossiers': 1,
#  'mischief': 1,
#  'lip': 1,
#  'synch': 1,
#  'viseme': 1,
#  'companions': 1,
#  'extended': 1,
#  'approximated': 1,
#  'ambassadors': 1,
#  'celebrities': 1,
#  'unreal': 1,
#  'reallusion': 1,
#  'unscattered': 1,
#  'heights': 1,
#  'geometry': 1,
#  'symmetric': 1,
#  'eigenvalues': 1,
#  'eigenvectors': 1,
#  'provability': 1,
#  'bayes’': 1,
#  'joint': 1,
#  'multinomial': 1,
#  'mle': 1,
#  'posterior': 1,
#  'posteriori': 1,
#  'modelers': 1,
#  'subjected': 1,
#  'finalizing': 1,
#  'comparatively': 1,
#  'tread': 1,
#  'hows': 1,
#  'logarithmic': 1,
#  'silhouette': 1,
#  'aplenty': 1,
#  'familiarised': 1,
#  'scikit': 1,
#  'theano': 1,
#  'mllib': 1,
#  'h2o': 1,
#  'knack': 1,
#  'convex': 1,
#  'forests': 1,
#  'proportionately': 1,
#  'perceptron': 1,
#  'cuny': 1,
#  'cental': 1,
#  'reproducible': 1,
#  'culminates': 1,
#  'jira': 1,
#  'singularly': 1,
#  'complementary': 1,
#  'jupyterhub': 1,
#  'tecton': 1,
#  'gitlab': 1,
#  'fiddler': 1,
#  'conjunctive': 1,
#  'noterm': 1,
#  'swimmer': 1,
#  'brown': 1,
#  'spoils': 1,
#  'varieties': 1,
#  'tainted': 1,
#  'pessimistic': 1,
#  'remembering': 1,
#  'residue': 1,
#  'cents': 1,
#  'benefitting': 1,
#  'rutgers': 1,
#  '“tech': 1,
#  '1972': 1,
#  '4hana': 1,
#  'sap’s': 1,
#  'qualtrics': 1,
#  'specializes': 1,
#  'altiscale': 1,
#  'bdaas': 1,
#  'renowned': 1,
#  'unilever': 1,
#  'salesforce’s': 1,
#  'einstein': 1,
#  '902': 1,
#  'marking': 1,
#  'manufactures': 1,
#  '125': 1,
#  'royce': 1,
#  'bluetalon': 1,
#  'microsoft’s': 1,
#  '“black': 1,
#  'box”': 1,
#  'evil': 1,
#  'extrapolated': 1,
#  'tradeoffs': 1,
#  'inflection': 1,
#  'reached—meaning': 1,
#  'overburdened': 1,
#  'models’': 1,
#  'adoption—allowing': 1,
#  'conjure': 1,
#  'painful': 1,
#  'disproportionally': 1,
#  'marginalized': 1,
#  'perilous': 1,
#  'peoples’': 1,
#  'inviting': 1,
#  'systems’': 1,
#  'stakeholders’': 1,
#  'deviated': 1,
#  'digestible': 1,
#  'catapult': 1,
#  'audibility': 1,
#  'xml': 1,
#  'bowling': 1,
#  'alley': 1,
#  'laser': 1,
#  'minutely': 1,
#  'collated': 1,
#  'deposited': 1,
#  'gurney': 1,
#  'fifteen': 1,
#  'touched': 1,
#  'plates': 1,
#  'prepress': 1,
#  'inking': 1,
#  'mixes': 1,
#  'kindle': 1,
#  'departure': 1,
#  'capitalism': 1,
#  ...}

# %%
len(sorted_word_count_dict)
# Out:
# 13042

# %%
tsne_plot(model, 500, sorted_word_count_dict)
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:11: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   # This is added back by InteractiveShellApp.init_path()

# %%
### Better scraping input
### Add TF-IDF
### Add PCA
